# %%
# Firstly, please note that the performance of google word2vec is better on big datasets. 
# In this example we are considering only 25000 training examples from the imdb dataset.
# Therefore, the performance is similar to the "bag of words" model.

# Importing libraries
import numpy as np
import pandas as pd
# BeautifulSoup is used to remove html tags from the text
from bs4 import BeautifulSoup 
import re # For regular expressions

# Stopwords can be useful to undersand the semantics of the sentence.
# Therefore stopwords are not removed while creating the word2vec model.
# But they will be removed  while averaging feature vectors.
from nltk.corpus import stopwords
import gensim
from gensim import corpora, models, similarities

import os

# %%
negatif_1 = pd.read_json("./xpanas.json")['title'].values.tolist()
negatif_2 = pd.read_json("./vibokep.json")['title'].values.tolist()
negatif_3 = pd.read_json("./bokep2017.json")['title'].values.tolist()
negatif_4 = pd.read_json("./aora.json")['title'].values.tolist()
negatif_5 = pd.read_json("./bbindo.json")['title'].values.tolist()
positif_paragraf = pd.read_json("./onclinic.json")['content'].values.tolist()

# %%
negatif = negatif_1 + negatif_2 + negatif_3 + negatif_4 + negatif_5

# %%
len(negatif)
# Out:
# 1572

# %%
positif = []
for x in positif_paragraf:
    for y in x.split('.'):
        for z in y.split('.'):
            positif.append(z)

# %%
positif[123]
# Out:
# ' Semua pelayanan mengacu kepada standar pelayanan ON CLINIC INTERNATIONAL yang berpusat di Australia'

# %%
positif = [x.lower() for x in positif]
negatif = [x.lower() for x in negatif]

# %%
negatif[123]
# Out:
# 'pelajar ml di dalam bus sekolah'

# %%
len(positif)
# Out:
# 634

# %%
from sklearn.model_selection import train_test_split

# %%
pos_train, pos_test = train_test_split(positif, test_size=0.2)
neg_train, neg_test = train_test_split(negatif, test_size=0.2)

# %%
len(pos_train)
# Out:
# 507

# %%
len(pos_test)
# Out:
# 127

# %%
pos_label = np.ones(len(pos_train),dtype=int)
neg_label = np.zeros(len(neg_train),dtype=int)

# %%
df_pos = pd.DataFrame({'review':pos_train, 'sentiment':pos_label})
df_neg = pd.DataFrame({'review':neg_train, 'sentiment':neg_label})

# %%
frames = [df_pos, df_neg]
df_train = pd.concat(frames)
df_test = pd.DataFrame({'review':pos_test + neg_test})

# %%
df_train
# Out:
#                                                  review  sentiment
# 0      atas dukungan isteri, robi pun akhirnya menda...          1
# 1      dengan 15 klinik yang tersebar di banyak kota...          1
# 2      \ns/ skrg ibu minum terus racikan tsb, bahkan...          1
# 3      \n berkurangnya rasa cinta merupakan hal yang...          1
# 4      untuk mempermudah menuju solusi mengatasi eja...          1
# 5      tetapi jika anda mengalami sakit punggung, ya...          1
# 6      faktanya, banyak sekali hubungan yang gagal k...          1
# 7                                                     8          1
# 8     id/explore-sex/artikel/kamu-dia/mempertahankan...          1
# 9      jarang ditemukan adanya inkontinensia desakan...          1
# 10                                                   13          1
# 11     ketika   menjadi masalah yang terus-menerus, ...          1
# 12                                                               1
# 13     dia menemukan bahwa pasien yang terlibat dala...          1
# 14    seminggu kemudian ibu baru bilang terasa sakit...          1
# 15     di akhir minggu, anda akan lebih menyadari pe...          1
# 16                                                               1
# 17     * pernah setelah membaca tulisan ini, seorang...          1
# 18    stres, dibebani dengan masalah kesulitan hidup...          1
# 19     so, mari sayangi jantung kita agar hidup lebi...          1
# 20                                                   co          1
# 21     \nsejak itu aku melakukan senam lidah setiap ...          1
# 22                                                    2          1
# 23     \n* sex : dapat membuat penampilan seseorang ...          1
# 24     karena itu, sangat dianjurkan untuk melakukan...          1
# 25     hormon seks yang termasuk ke dalam hormon per...          1
# 26     pada wanita, umumnya inkontinensia urin merup...          1
# 27     namun studi ini gagal untuk mempelajari penga...          1
# 28     pengobatan di on clinic ditangani oleh dokter...          1
# 29                                                 \n 3          1
# ...                                                 ...        ...
# 1227  colokin memek cewek cantik dan nikmatin aja ex...          0
# 1228                           video lucah janda melayu          0
# 1229              video janda muda bispak doyan ngentot          0
# 1230            video ngentot abg bispak dipuncak bogor          0
# 1231                      video abg ngentot dalam mobil          0
# 1232                             masturbasi pakai mesin          0
# 1233                                ngentot cewek binal          0
# 1234  cewek berjilbab cantik sange dan masturbasi di...          0
# 1235          video cabe – cabean belajar ngemut kontol          0
# 1236   cewek jepang seksi, cantik dan tetntunya bahenol          0
# 1237                mahasiswi simpanan habis digangbang          0
# 1238             cewek jepang ngentot sampai keringatan          0
# 1239           video cewek arab blasteran lagi di entot          0
# 1240                                  video bokep luela          0
# 1241             suster ai suzuki ngajak pasien ngentot          0
# 1242         ngentot babysitters abg yang sangat cantik          0
# 1243           janda muda selingkuh sama suami tetangga          0
# 1244                      jilboobs pink cantik keenakan          0
# 1245       manis dan mulusnya body cewek abg tetanggaku          0
# 1246                       berbagi istri sama pria lain          0
# 1247       memek temben istri baju biru di sodok nikmat          0
# 1248         bispak abg memek sempit melayani pelanggan          0
# 1249  memek di gesek make kontol baru di masukin bia...          0
# 1250                        bispak memek sempit dan hot          0
# 1251                    ngintip pasangan mesum anak sma          0
# 1252     bokep jepang berbagi istri dengan teman kantor          0
# 1253                  ngentot bareng pacar di kontrakan          0
# 1254                         cantik 18 tahun masturbasi          0
# 1255                           ngintip spg mall ngentot          0
# 1256             anak smp pamer uting di bigo live 2017          0
#
# [1764 rows x 2 columns]

# %%
df_test
# Out:
#                                                 review
# 0     jika terjadinya sekali-dua kali saja mungkin ...
# 1     hal ini bisa dikaitkan dengan meningkatnya im...
# 2     \n* sex : terhindar dari resiko atrofi (penge...
# 3     namun, jumlah rata-rata itu lebih besar dua k...
# 4     \n* sex : obat penenang yang paling aman di d...
# 5     itu sebabnya, jika anda mengalami masalah gan...
# 6     so, stop ya penggunaan obat kuat, beralihlah ...
# 7     tetapi jika terlalu sering dan terus dibiarka...
# 8     impiannya tentang kebahagiaan justru nyaris t...
# 9
# 10    apalah artinya hubungan seks jika tidak diser...
# 11    tetapi begitu sibuk dengan anak-anak sehingga...
# 12                                       \nluar biasa
# 13    jadi pada saat penderita merasakan akan ejaku...
# 14    seseorang yang berhubungan seks secara teratu...
# 15           id atau email :  prostate_health@onclinic
# 16    lakukan sekarang untuk sehat selamanya! jika ...
# 17                              9050, bogor (0251) 831
# 18    erlich, seorang spesialis arthritis dari phil...
# 19    normalnya, ereksi bisa tercapai bila ada peni...
# 20
# 21   kebanyakan pria menganggap merokok membuat ter...
# 22    \nseminggu 2x diinfus & terapi (biayanya luma...
# 23    sementara itu, pria yang mengisap lebih dari ...
# 24    menurut riset american heart associations ann...
# 25                             000, surabaya (031) 547
# 26    turunkan kaki dan duduk di tepi ranjang selam...
# 27    tidak ada jalan lain kecuali menuntaskan sege...
# 28                    \n* sex : mengurangi berat badan
# 29    yang penting harus tepat berobatnya!” jack va...
# ..                                                 ...
# 412                               bokep dillion harper
# 413                               jual pacar demi uang
# 414                            ngentot anak orang kaya
# 415  games kocak yang bikin ente bisa ngenot sepuas...
# 416     video ngentot janda crot di mulut telan sperma
# 417                      video ngentot cewek berjilbab
# 418         awalnya dipijat malah nafsu pengen ngentot
# 419  film dewasa jadul indo nafsu birahi membara ma...
# 420                       ketangkap basah saat ngentot
# 421               ngedoggy cewek paling cakep dikampus
# 422           pramugari ml sama pilot di dalam pesawat
# 423                               ngentot istri cantik
# 424  joget dengan body kayak gini tetap aja bikin s...
# 425                ngentot di hari ulang tahun pacarku
# 426               video kimcil cantik lagi sange berat
# 427                video cewek cina muda nyepong pacar
# 428      bokep jilbabers berkacamata nyepong di toilet
# 429                             kimcil abg di gangbang
# 430             akibat istri di tinggal pergi kelamaan
# 431         video tkw edan, bugil sambil ngoceh-ngoceh
# 432           video ngentot adik teman yang masih lugu
# 433                            ngentot anak bispak sma
# 434               ngentot pacar sambil mainan hadphone
# 435  ngentot istri bokong semong berkaca mata = lua...
# 436                   bule ngentot dengan bispak binal
# 437                          di wot sama toge bra pink
# 438                      2 cewek cantik rebutan kontol
# 439               ngentot mahasiswo cantik dalam mobil
# 440  kelakuan cewek asrama putri lagi belajar jadi ...
# 441                     cewek cantik bugil dikontrakan
#
# [442 rows x 1 columns]

# %%
# This function converts a text to a sequence of words.
def review_wordlist(review, remove_stopwords=False):
    # 1. Removing html tags
    review_text = BeautifulSoup(review).get_text()
    # 2. Removing non-letter.
    review_text = re.sub("[^a-zA-Z]"," ",review_text)
    # 3. Converting to lower case and splitting
    words = review_text.lower().split()
    # 4. Optionally remove stopwords
    if remove_stopwords:
        stops = set(stopwords.words("english"))     
        words = [w for w in words if not w in stops]
    
    return(words)

# %%
# word2vec expects a list of lists.
# Using punkt tokenizer for better splitting of a paragraph into sentences.

import nltk.data
#nltk.download('popular')

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
# This function splits a review into sentences
def review_sentences(review, tokenizer, remove_stopwords=False):
    # 1. Using nltk tokenizer
    raw_sentences = tokenizer.tokenize(review.strip())
    sentences = []
    # 2. Loop for each sentence
    for raw_sentence in raw_sentences:
        if len(raw_sentence)>0:
            sentences.append(review_wordlist(raw_sentence,\
                                            remove_stopwords))

    # This returns the list of lists
    return sentences

# %%
sentences = []
print("Parsing sentences from training set")
for review in df_train["review"]:
    sentences += review_sentences(review, tokenizer)
# Out:
# Parsing sentences from training set
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
sentences
# Out:
# [['atas',
#   'dukungan',
#   'isteri',
#   'robi',
#   'pun',
#   'akhirnya',
#   'mendatangi',
#   'klinik',
#   'yang',
#   'dipercaya',
#   'memiliki',
#   'tingkat',
#   'keberhasilan',
#   'yang',
#   'sangat',
#   'tinggi',
#   'dalam',
#   'mengobati',
#   'hingga',
#   'tuntas',
#   'ini'],
#  ['dengan',
#   'klinik',
#   'yang',
#   'tersebar',
#   'di',
#   'banyak',
#   'kota',
#   'di',
#   'indonesia',
#   'on',
#   'clinic',
#   'dipercaya',
#   'memiliki',
#   'tingkat',
#   'keberhasilan',
#   'yang',
#   'sangat',
#   'tinggi',
#   'dalam',
#   'mengobati',
#   'ejakulasi',
#   'dini',
#   'hingga',
#   'tuntas'],
#  ['s',
#   'skrg',
#   'ibu',
#   'minum',
#   'terus',
#   'racikan',
#   'tsb',
#   'bahkan',
#   'setiap',
#   'pagi',
#   'ibu',
#   'sekarang',
#   'th',
#   'lakukan',
#   'treadmill',
#   'yg',
#   'injakan',
#   'kaki',
#   'naik',
#   'turun',
#   'itu',
#   'rutin',
#   's',
#   'd',
#   'sekarang'],
#  ['berkurangnya',
#   'rasa',
#   'cinta',
#   'merupakan',
#   'hal',
#   'yang',
#   'sering',
#   'terjadi',
#   'terutama',
#   'pada',
#   'pasangan',
#   'yang',
#   'sudah',
#   'menjalin',
#   'hubungan',
#   'dalam',
#   'jangka',
#   'waktu',
#   'yang',
#   'lama'],
#  ['untuk',
#   'mempermudah',
#   'menuju',
#   'solusi',
#   'mengatasi',
#   'ejakulasi',
#   'dini',
#   'sebaiknya',
#   'ingat',
#   'petuah',
#   'lama',
#   'ini',
#   'malu',
#   'bertanya',
#   'sesat',
#   'di',
#   'jalan'],
#  ['tetapi',
#   'jika',
#   'anda',
#   'mengalami',
#   'sakit',
#   'punggung',
#   'yang',
#   'terbaik',
#   'adalah',
#   'berkonsultasi',
#   'dengan',
#   'dokter'],
#  ['faktanya',
#   'banyak',
#   'sekali',
#   'hubungan',
#   'yang',
#   'gagal',
#   'karena',
#   'masing',
#   'masing',
#   'tidak',
#   'membicarakan',
#   'apa',
#   'yang',
#   'dirasakan',
#   'terhadap',
#   'satu',
#   'sama',
#   'lain'],
#  [],
#  ['id',
#   'explore',
#   'sex',
#   'artikel',
#   'kamu',
#   'dia',
#   'mempertahankan',
#   'rasa',
#   'cinta',
#   'terhadap',
#   'pasangan'],
#  ['jarang',
#   'ditemukan',
#   'adanya',
#   'inkontinensia',
#   'desakan',
#   'dimana',
#   'didapatkan',
#   'keinginan',
#   'miksi',
#   'mendadak'],
#  [],
#  ['ketika',
#   'menjadi',
#   'masalah',
#   'yang',
#   'terus',
#   'menerus',
#   'tidak',
#   'hanya',
#   'rumah',
#   'tangga',
#   'yang',
#   'retak',
#   'tetapi',
#   'juga',
#   'hal',
#   'hal',
#   'lain',
#   'termasuk',
#   'kualitas',
#   'hidup',
#   'prestasi',
#   'kerja',
#   'dan',
#   'power',
#   'pria',
#   'menjadi',
#   'terganggu',
#   'akibat',
#   'hilangnya',
#   'rasa',
#   'percaya',
#   'diri'],
#  ['dia',
#   'menemukan',
#   'bahwa',
#   'pasien',
#   'yang',
#   'terlibat',
#   'dalam',
#   'seks',
#   'mengalami',
#   'sedikit',
#   'rasa',
#   'sakit'],
#  ['seminggu',
#   'kemudian',
#   'ibu',
#   'baru',
#   'bilang',
#   'terasa',
#   'sakit',
#   'dipunggungnya'],
#  ['di',
#   'akhir',
#   'minggu',
#   'anda',
#   'akan',
#   'lebih',
#   'menyadari',
#   'perasaan',
#   'cinta',
#   'anda',
#   'pada',
#   'pasangan'],
#  ['pernah',
#   'setelah',
#   'membaca',
#   'tulisan',
#   'ini',
#   'seorang',
#   'usia',
#   'lanjut',
#   'menangis',
#   'menyesali',
#   'kenapa',
#   'tdk',
#   'mengetahui',
#   'hal',
#   'ini',
#   'jauh',
#   'hari'],
#  ['stres',
#   'dibebani',
#   'dengan',
#   'masalah',
#   'kesulitan',
#   'hidup',
#   'dan',
#   'ketakutan',
#   'bahwa',
#   'kesehatan',
#   'anda',
#   'menurun'],
#  ['dan',
#   'disini',
#   'seks',
#   'adalah',
#   'jawaban',
#   'untuk',
#   'kebahagiaan',
#   'umur',
#   'panjang',
#   'dan',
#   'tubuh',
#   'yang',
#   'sehat'],
#  ['so',
#   'mari',
#   'sayangi',
#   'jantung',
#   'kita',
#   'agar',
#   'hidup',
#   'lebih',
#   'terjaga'],
#  ['co'],
#  ['sejak', 'itu', 'aku', 'melakukan', 'senam', 'lidah', 'setiap', 'hari'],
#  [],
#  ['sex',
#   'dapat',
#   'membuat',
#   'penampilan',
#   'seseorang',
#   'selalu',
#   'gembira',
#   'bahagia'],
#  ['karena',
#   'itu',
#   'sangat',
#   'dianjurkan',
#   'untuk',
#   'melakukan',
#   'berbagai',
#   'kegiatan',
#   'yang',
#   'menjadi',
#   'hobi',
#   'untuk',
#   'mengisi',
#   'waktu',
#   'luang',
#   'tapi',
#   'ingatlah',
#   'untuk',
#   'tidak',
#   'berlebihan',
#   'juga'],
#  ['hormon',
#   'seks',
#   'yang',
#   'termasuk',
#   'ke',
#   'dalam',
#   'hormon',
#   'pertumbuhan',
#   'manusia',
#   'inilah',
#   'yang',
#   'berperan',
#   'sangat',
#   'penting',
#   'untuk',
#   'membuat',
#   'seseorang',
#   'awet',
#   'muda',
#   'atau',
#   'tampak',
#   'lebih',
#   'muda'],
#  ['pada',
#   'wanita',
#   'umumnya',
#   'inkontinensia',
#   'urin',
#   'merupakan',
#   'inkontinensia',
#   'stres',
#   'artinya',
#   'keluarnya',
#   'urin',
#   'semata',
#   'mata',
#   'karena',
#   'melahirkan',
#   'batuk',
#   'bersin',
#   'dan',
#   'segala',
#   'gerakan',
#   'lain',
#   'seperti',
#   'olahraga'],
#  ['namun',
#   'studi',
#   'ini',
#   'gagal',
#   'untuk',
#   'mempelajari',
#   'pengaruh',
#   'seks',
#   'di',
#   'jantung',
#   'seorang',
#   'wanita'],
#  ['pengobatan',
#   'di',
#   'on',
#   'clinic',
#   'ditangani',
#   'oleh',
#   'dokter',
#   'dokter',
#   'berpengalaman',
#   'sesuai',
#   'standar',
#   'on',
#   'clinic',
#   'international',
#   'yang',
#   'berpusat',
#   'di',
#   'australia',
#   'dan',
#   'memberikan',
#   'tingkat',
#   'penyembuhan',
#   'yang',
#   'tinggi',
#   'diatas',
#   'dengan',
#   'tetap',
#   'menjaga',
#   'kerahasiaan',
#   'dan',
#   'privasi',
#   'pasien',
#   'seutuhnya'],
#  [],
#  ['membangun',
#   'hormon',
#   'oksitosin',
#   'kepercayaan',
#   'dan',
#   'membawa',
#   'pasangan',
#   'lebih',
#   'dekat',
#   'dan',
#   'juga',
#   'asmara'],
#  ['namun',
#   'penting',
#   'untuk',
#   'diingat',
#   'bahwa',
#   'putusnya',
#   'hubungan',
#   'tersebut',
#   'bukanlah',
#   'akhir',
#   'dari',
#   'segalanya'],
#  ['itu', 'setara', 'dengan', 'joging', 'km'],
#  ['menarik',
#   'napas',
#   'secara',
#   'kuat',
#   'meningkatkan',
#   'jumlah',
#   'oksigen',
#   'dalam',
#   'sel',
#   'anda',
#   'dan',
#   'testosteron',
#   'yang',
#   'dihasilkan',
#   'selama',
#   'seks',
#   'membuat',
#   'tulang',
#   'dan',
#   'otot',
#   'yang',
#   'kuat'],
#  ['akibatnya',
#   'dia',
#   'sekarang',
#   'mengalami',
#   'kelumpuhan',
#   'dan',
#   'tdk',
#   'bisa',
#   'meninggalkan',
#   'tempat',
#   'tidur',
#   'tulang',
#   'punggungnya',
#   'mengalami',
#   'cedera'],
#  ['on',
#   'clinic',
#   'indonesia',
#   'adalah',
#   'jaringan',
#   'layanan',
#   'kesehatan',
#   'yang',
#   'dapat',
#   'mengatasi',
#   'problem',
#   'seksual',
#   'pria',
#   'yaitu',
#   'impotensi',
#   'serta',
#   'problem',
#   'seksual',
#   'perempuan',
#   'yang',
#   'mengalami',
#   'pengobatan',
#   'di',
#   'on',
#   'clinic',
#   'memberikan',
#   'keberhasilan',
#   'pengobatan',
#   'yang',
#   'tinggi',
#   'sesuai',
#   'standar',
#   'on',
#   'clinic',
#   'international',
#   'yang',
#   'berpusat',
#   'di',
#   'australia',
#   'dengan',
#   'menjaga',
#   'privacy'],
#  ['pria',
#   'paruh',
#   'baya',
#   'selama',
#   'satu',
#   'dekade',
#   'dan',
#   'menyimpulkan',
#   'bahwa',
#   'aktivitas',
#   'seksual',
#   'mungkin',
#   'memiliki',
#   'efek',
#   'perlindungan',
#   'pada',
#   'kesehatan'],
#  ['wah', 'sy', 'stres'],
#  ['seminggu',
#   'kemudian',
#   'ibu',
#   'ingin',
#   'mencoba',
#   'tips',
#   'kesehatan',
#   'yg',
#   'kebetulan',
#   'dibacanya',
#   'pada',
#   'sisipan',
#   'artikel',
#   'kecil',
#   'tipsnya',
#   'rebuslah',
#   'lembar',
#   'daun',
#   'salam',
#   'bh',
#   'bawang',
#   'bombay',
#   'yg',
#   'di',
#   'iris',
#   'dlm',
#   'gelas',
#   'air',
#   'sampai',
#   'tinggal',
#   'gelas',
#   'kmd',
#   'air',
#   'rebusannya',
#   'diminum',
#   'setiap',
#   'hari'],
#  ['pada',
#   'kasus',
#   'yang',
#   'ringan',
#   'para',
#   'ahli',
#   'biasanya',
#   'hanya',
#   'merekomendasikan',
#   'beberapa',
#   'metode',
#   'untuk',
#   'mulai',
#   'dari',
#   'latihan',
#   'menguatkan',
#   'otot',
#   'penis',
#   'hingga',
#   'merelaksasi',
#   'tubuh',
#   'melalui',
#   'tekhnik',
#   'berhenti',
#   'kemudian',
#   'mulai',
#   'sehingga',
#   'penderita',
#   'terlatih',
#   'dalam',
#   'mengkondisikan',
#   'kepuasan',
#   'tanpa',
#   'terjadinya',
#   'ejakulasi'],
#  ['belajarlah',
#   'bagaimana',
#   'mendengarkan',
#   'bagaimana',
#   'berbicara',
#   'sehingga',
#   'mereka',
#   'didengar',
#   'bagaimana',
#   'untuk',
#   'jujur',
#   'meminta',
#   'apa',
#   'yang',
#   'diinginkan',
#   'bagaimana',
#   'mengatakan',
#   'ya',
#   'bagaimana',
#   'mengatakan',
#   'tidak'],
#  ['lampung'],
#  ['untuk',
#   'mempermudah',
#   'jalan',
#   'anda',
#   'menuju',
#   'solusi',
#   'mengatasi',
#   'ejakulasi',
#   'dini',
#   'sebaiknya',
#   'ingat',
#   'petuah',
#   'lama',
#   'ini',
#   'malu',
#   'bertanya',
#   'sesat',
#   'di',
#   'jalan'],
#  ['tetapi',
#   'jika',
#   'terlalu',
#   'sering',
#   'itu',
#   'lain',
#   'cerita',
#   'mengingat',
#   'seks',
#   'adalah',
#   'hubungan',
#   'mutualis',
#   'yang',
#   'sudah',
#   'seharusnya',
#   'dinikmati',
#   'bersama',
#   'hingga',
#   'akhir'],
#  ['perlu',
#   'diakui',
#   'bahwa',
#   'menghentikan',
#   'kebiasaan',
#   'merokok',
#   'terlebih',
#   'pada',
#   'perokok',
#   'berat',
#   'bukanlah',
#   'hal',
#   'yang',
#   'mudah'],
#  ['dianjurkan',
#   'oleh',
#   'para',
#   'ahli',
#   'utk',
#   'menjalankan',
#   'kali',
#   'menit',
#   'yakni'],
#  ['padahal',
#   'impotensi',
#   'sangat',
#   'mudah',
#   'diobati',
#   'bahkan',
#   'disembuhkan'],
#  ['saat',
#   'baru',
#   'putus',
#   'rasanya',
#   'seseorang',
#   'tidak',
#   'akan',
#   'mau',
#   'buru',
#   'buru',
#   'pacaran',
#   'lagi',
#   'karena',
#   'masih',
#   'terngiang',
#   'dengan',
#   'mantan',
#   'yang',
#   'memiliki',
#   'kesempurnaan',
#   'sedemikian',
#   'rupa'],
#  ['pasti', 'anda', 'akan', 'merasa', 'lebih', 'dekat', 'dengan', 'pasangan'],
#  ['tentunya',
#   'itu',
#   'semua',
#   'dilakukan',
#   'dalam',
#   'batas',
#   'wajar',
#   'bukan',
#   'berarti',
#   'menjadi',
#   'gila',
#   'gilaan',
#   'melakukan',
#   'hal',
#   'yang',
#   'disukai',
#   'demi',
#   'melupakan',
#   'mantan',
#   'dan',
#   'ingat',
#   'juga',
#   'jangan',
#   'sampai',
#   'mengabaikan',
#   'kewajiban',
#   'rutin',
#   'kita',
#   'sehari',
#   'hari'],
#  ['para',
#   'ahli',
#   'dokter',
#   'ahli',
#   'syaraf',
#   'sering',
#   'berpesan',
#   'setiap',
#   'orang',
#   'hrs',
#   'memperhatikan',
#   'x',
#   'menit'],
#  ['semarang'],
#  [],
#  ['apa', 'sajakah', 'itu'],
#  ['patti', 'britton', 'ph'],
#  ['dalam',
#   'sebuah',
#   'penelitian',
#   'yang',
#   'dipublikasikan',
#   'dalam',
#   'public',
#   'library',
#   'of',
#   'science',
#   'jurnal',
#   'tiga',
#   'peneliti',
#   'neuroscience',
#   'melakukan',
#   'tes',
#   'pada',
#   'tikus',
#   'jantan',
#   'dan',
#   'menemukan',
#   'bahwa',
#   'tikus',
#   'yang',
#   'aktif',
#   'secara',
#   'seksual',
#   'berkurang',
#   'kecemasannya',
#   'daripada',
#   'tikus',
#   'tanpa',
#   'aktivitas',
#   'seksual'],
#  ['memakai',
#   'namanya',
#   'menjadi',
#   'bagian',
#   'diri',
#   'anda',
#   'setelah',
#   'berpisah',
#   'dari',
#   'pasangan',
#   'anda',
#   'pasti',
#   'merasa',
#   'sedih',
#   'dan',
#   'terpukul'],
#  ['manusia',
#   'tidak',
#   'lepas',
#   'dari',
#   'sex',
#   'dimana',
#   'ini',
#   'adalah',
#   'kebutuhan',
#   'pokok',
#   'bagi',
#   'mereka',
#   'sehingga',
#   'banyak',
#   'orang',
#   'orang',
#   'melakukan',
#   'jalan',
#   'pintas',
#   'untuk',
#   'bisa',
#   'merasa',
#   'hebat',
#   'dalam',
#   'berhubungan',
#   'seperti',
#   'minum',
#   'obat',
#   'kuat',
#   'padahal',
#   'dampak',
#   'dari',
#   'obat',
#   'kuat',
#   'sangatlah',
#   'buruk',
#   'untuk',
#   'kesehatan'],
#  ['eh',
#   'setlh',
#   'hari',
#   'ibu',
#   'sdh',
#   'dpt',
#   'berjalan',
#   'lagi',
#   'seminggu',
#   'kemudian',
#   'berjlnnya',
#   'sdh',
#   'cepat',
#   'rasa',
#   'sakitnya',
#   'baik',
#   'dipaha',
#   'maupun',
#   'di',
#   'punggung',
#   'jadi',
#   'hilang'],
#  ['karena',
#   'tidak',
#   'sedikit',
#   'orang',
#   'yang',
#   'dikarenakan',
#   'malu',
#   'jika',
#   'kondisinya',
#   'diketahui',
#   'orang',
#   'lalu',
#   'mencoba',
#   'mencari',
#   'jalan',
#   'sendiri',
#   'untuk',
#   'mengatasi',
#   'masalah',
#   'ejakulasi',
#   'dini',
#   'dengan',
#   'cara',
#   'yang',
#   'tidak',
#   'dianjurkan',
#   'bahkan',
#   'malah',
#   'bisa',
#   'mengancam',
#   'kesehatannya'],
#  ['sex',
#   'dapat',
#   'memperpanjang',
#   'usia',
#   'pria',
#   'tahun',
#   'lebih',
#   'panjang',
#   'dibandingkan',
#   'dengan',
#   'orang',
#   'yang',
#   'jarang',
#   'melakukannya'],
#  ['h'],
#  ['prevalensi',
#   'meningkat',
#   'sampai',
#   'pada',
#   'pasien',
#   'usia',
#   'lebih',
#   'dari',
#   'tahun'],
#  ['semula',
#   'robi',
#   'menganggap',
#   'bahwa',
#   'kondisinya',
#   'ini',
#   'wajar',
#   'dan',
#   'bukan',
#   'penyakit',
#   'yang',
#   'mesti',
#   'disikapi',
#   'serius'],
#  ['memperkuat',
#   'otot',
#   'panggul',
#   'seks',
#   'melibatkan',
#   'penggunaan',
#   'beberapa',
#   'otot',
#   'maka',
#   'hubungan',
#   'seksual',
#   'secara',
#   'teratur',
#   'dapat',
#   'membantu',
#   'anda',
#   'mengembangkan',
#   'otot',
#   'panggul',
#   'lebih',
#   'kuat'],
#  ['gsm', 'kode', 'area'],
#  ['inilah',
#   'yang',
#   'disebut',
#   'dengan',
#   'benign',
#   'prostatic',
#   'hyperplasia',
#   'atau',
#   'bph'],
#  ['medan'],
#  ['australia',
#   'juga',
#   'mencatat',
#   'hasil',
#   'yang',
#   'hampir',
#   'sama',
#   'yaitu',
#   'dari'],
#  ['informasi',
#   'lebih',
#   'lanjut',
#   'hubungi',
#   'pulsa',
#   'lokal',
#   'sms',
#   'pin',
#   'fbf',
#   'f',
#   'wa'],
#  ['bila',
#   'saat',
#   'ini',
#   'sudah',
#   'cukup',
#   'lama',
#   'anda',
#   'tidak',
#   'bercinta',
#   'dengan',
#   'pasangan',
#   'dan',
#   'kehilangan',
#   'hasrat',
#   'untuk',
#   'melakukannya',
#   'cobalah',
#   'untuk',
#   'memaksakan',
#   'diri',
#   'melakukan',
#   'hubungan',
#   'seks',
#   'dengan',
#   'suami',
#   'selama',
#   'satu',
#   'minggu',
#   'penuh'],
#  ['jangan',
#   'biarkan',
#   'sebuah',
#   'masalah',
#   'ataupun',
#   'perasaan',
#   'mengganjal',
#   'tertahan',
#   'terlalu',
#   'lama',
#   'dan',
#   'nantinya',
#   'akan',
#   'meledak',
#   'pada',
#   'suatu',
#   'saat'],
#  ['hidup',
#   'lebih',
#   'lama',
#   'jantung',
#   'yang',
#   'sehat',
#   'otot',
#   'kuat',
#   'sirkulasi',
#   'peningkatan',
#   'oksigen',
#   'dan',
#   'kebahagiaan',
#   'adalah',
#   'beberapa',
#   'faktor',
#   'yang',
#   'memperpanjang',
#   'hidup',
#   'bertahun',
#   'tahun'],
#  ['jack',
#   'vaisman',
#   'direktur',
#   'on',
#   'clinic',
#   'international',
#   'impotensi',
#   'sangat',
#   'bisa',
#   'disembuhkan'],
#  ['berkurangnya',
#   'rasa',
#   'cinta',
#   'merupakan',
#   'hal',
#   'yang',
#   'sering',
#   'terjadi',
#   'terutama',
#   'terdapat',
#   'sebuah',
#   'hasil',
#   'penelitian',
#   'yang',
#   'menyatakan',
#   'bahwa',
#   'satu',
#   'dari',
#   'lima',
#   'perkawinan',
#   'di',
#   'dunia',
#   'ternyata',
#   'berakhir',
#   'dengan',
#   'perceraian'],
#  ['heart',
#   'check',
#   'menggunakan',
#   'terobosan',
#   'baru',
#   'teknologi',
#   'ekg',
#   'hanya',
#   'menit'],
#  ['cardiologist',
#   'akan',
#   'membaca',
#   'bisa',
#   'mendeteksi',
#   'gangguan',
#   'terkecil',
#   'dr',
#   'fungsi',
#   'jantung',
#   'anda'],
#  ['hal',
#   'ini',
#   'bukan',
#   'saja',
#   'tidak',
#   'bisa',
#   'mengatur',
#   'merawat',
#   'diri',
#   'tapi',
#   'akan',
#   'merepotkan',
#   'dan',
#   'menyusahkan',
#   'sanak',
#   'keluarga',
#   'dan',
#   'orang',
#   'lain'],
#  ['yang',
#   'harus',
#   'diingat',
#   'adalah',
#   'bahwa',
#   'hidup',
#   'anda',
#   'belum',
#   'berakhir',
#   'saat',
#   'putus',
#   'atau',
#   'berpisah',
#   'dari',
#   'pasangan',
#   'pastinya',
#   'kebanyakan',
#   'orang',
#   'akan',
#   'merasa',
#   'sedih',
#   'dan',
#   'patah',
#   'hati'],
#  ['jika',
#   'kondisi',
#   'ini',
#   'dibiarkan',
#   'risikonya',
#   'adalah',
#   'air',
#   'seni',
#   'yang',
#   'terperangkap',
#   'bisa',
#   'mengakibatkan',
#   'infeksi',
#   'pada',
#   'hati',
#   'dan',
#   'ginjal',
#   'serta',
#   'jaringan',
#   'yang',
#   'terdapat',
#   'disekitar',
#   'kandung',
#   'kemih',
#   'dan',
#   'saluran',
#   'kencing'],
#  ['sudah',
#   'cukup',
#   'banyak',
#   'pria',
#   'dengan',
#   'impotensi',
#   'yang',
#   'berobat',
#   'namun',
#   'kerap',
#   'belum',
#   'mengalami',
#   'penyembuhan',
#   'berarti'],
#  ['apakah',
#   'anda',
#   'punya',
#   'masalah',
#   'dalam',
#   'mengontrol',
#   'buang',
#   'air',
#   'kecil'],
#  ['sering',
#   'kebelet',
#   'buang',
#   'air',
#   'kecil',
#   'yang',
#   'mengganggu',
#   'tidur',
#   'buang',
#   'air',
#   'kecil',
#   'ber',
#   'kali',
#   'kali',
#   'kalau',
#   'mau',
#   'pipis',
#   'tidak',
#   'bisa',
#   'dikontrol',
#   'tiba',
#   'tiba',
#   'pipis',
#   'nya',
#   'sudah',
#   'keluar',
#   'sehingga',
#   'banyak',
#   'pasien',
#   'yang',
#   'harus',
#   'memakai',
#   'pampers'],
#  ['redaksi', 'http', 'www'],
#  ['jadi',
#   'tidak',
#   'ada',
#   'cara',
#   'lebih',
#   'baik',
#   'selain',
#   'melakukan',
#   'gaya',
#   'hidup',
#   'sehat',
#   'serta',
#   'diagnosa',
#   'sedini',
#   'mungkin',
#   'agar',
#   'dapat',
#   'diupayakan',
#   'tindakan',
#   'pengobatan',
#   'secara',
#   'komprehensif'],
#  ['banyak',
#   'orang',
#   'ketika',
#   'ditanya',
#   'soal',
#   'bagamana',
#   'kiat',
#   'yang',
#   'paling',
#   'tepat',
#   'untuk',
#   'menjaga',
#   'kesehatan',
#   'tubuh',
#   'jawabannya',
#   'tidak',
#   'jauh',
#   'dari',
#   'mengatur',
#   'pola',
#   'makan',
#   'dan',
#   'berolahraga',
#   'secara',
#   'teratur'],
#  ['memicu',
#   'tidur',
#   'setelah',
#   'olahraga',
#   'cukup',
#   'banyak',
#   'dan',
#   'menguras',
#   'tenaga',
#   'anda',
#   'cenderung',
#   'mendapatkan',
#   'tidur',
#   'yang',
#   'nyaman'],
#  ['membuat',
#   'anda',
#   'lebih',
#   'muda',
#   'bercinta',
#   'tiga',
#   'kali',
#   'seminggu',
#   'dapat',
#   'membuat',
#   'anda',
#   'terlihat',
#   'tahun',
#   'lebih',
#   'muda',
#   'klaim',
#   'seorang',
#   'peneliti',
#   'dari',
#   'skotlandia'],
#  ['sy',
#   'ganti',
#   'dr',
#   'hasilnya',
#   'dikatakan',
#   'memang',
#   'sulit',
#   'krn',
#   'sdh',
#   'umur',
#   'osteoporosis',
#   'yg',
#   'sdh',
#   'agak',
#   'akut',
#   'ada',
#   'syaraf',
#   'yg',
#   'terkena',
#   'paling',
#   'diberi',
#   'vitamin',
#   'obat',
#   'penahan',
#   'rasa',
#   'nyeri'],
#  ['para',
#   'peneliti',
#   'dari',
#   'university',
#   'of',
#   'paisley',
#   'melakukan',
#   'percobaan',
#   'pada',
#   'yang',
#   'sama'],
#  [],
#  ['orang',
#   'australia',
#   'menunjukkan',
#   'bahwa',
#   'persen',
#   'pria',
#   'menikah',
#   'lebih',
#   'bahagia',
#   'daripada',
#   'laki',
#   'laki',
#   'single'],
#  ['entah',
#   'itu',
#   'dengan',
#   'obat',
#   'obatan',
#   'untuk',
#   'yang',
#   'tidak',
#   'diketahui',
#   'pasti',
#   'efek',
#   'sampingnya',
#   'atau',
#   'mendatangi',
#   'seseorang',
#   'yang',
#   'belum',
#   'jelas',
#   'kredibilitasnya'],
#  ['jd',
#   'dianjurkan',
#   'tidak',
#   'melakukan',
#   'perubahan',
#   'posisi',
#   'secara',
#   'mendadak',
#   'seperti',
#   'itu',
#   'utk',
#   'mencegah',
#   'hipotensi',
#   'postural'],
#  ['ditambah',
#   'lagi',
#   'dengan',
#   'informasi',
#   'yang',
#   'tidak',
#   'benar',
#   'membuat',
#   'mereka',
#   'lebih',
#   'memilih',
#   'mengkonsumsi',
#   'obat',
#   'kuat',
#   'ramuan',
#   'atau',
#   'menggunakan',
#   'minyak',
#   'oles',
#   'yang',
#   'beredar',
#   'bebas',
#   'dipasaran',
#   'dengan',
#   'harapan',
#   'bisa',
#   'sayangnya',
#   'dengan',
#   'cara',
#   'ini',
#   'ini',
#   'tidak',
#   'memberikan',
#   'hasil',
#   'positif',
#   'bahkan',
#   'bisa',
#   'sangat',
#   'merugikan',
#   'bagi',
#   'organ',
#   'organ',
#   'tubuh',
#   'khususnya',
#   'alat',
#   'vital',
#   'dan',
#   'alat',
#   'reproduksi'],
#  ['bila',
#   'terbangun',
#   'jgn',
#   'langsung',
#   'turun',
#   'dari',
#   'tempat',
#   'tidur',
#   'tetapi',
#   'berbaringlah',
#   'selama',
#   'mnt'],
#  ['co'],
#  ['perceraian',
#   'tersebut',
#   'tidak',
#   'selalu',
#   'diakibatkan',
#   'oleh',
#   'hadirnya',
#   'orang',
#   'ketiga',
#   'atau',
#   'perselingkuhan',
#   'namun',
#   'juga',
#   'disebabkan',
#   'oleh',
#   'berbagai',
#   'faktor',
#   'internal',
#   'rumah',
#   'tangga',
#   'itu',
#   'sendiri'],
#  ['oleh', 'karena', 'itu', 'anda', 'sudah', 'membakar', 'kalori'],
#  ['atau', 'sms', 'pin', 'bb', 'fd', 'f', 'f', 'www'],
#  [],
#  ['terkadang',
#   'seseorang',
#   'akan',
#   'menunjukkan',
#   'cinta',
#   'pada',
#   'pasangannya',
#   'dengan',
#   'caranya',
#   'ingin',
#   'diperlakukan',
#   'sebagai',
#   'bukti',
#   'bahwa',
#   'dia',
#   'dicintai'],
#  ['beragam',
#   'penelitian',
#   'telah',
#   'membuktikan',
#   'bahwa',
#   'hasrat',
#   'untuk',
#   'melakukan',
#   'hubungan',
#   'sex',
#   'saja',
#   'sudah',
#   'merangsang',
#   'energi',
#   'positif',
#   'yang',
#   'memicu',
#   'naiknya',
#   'sistem',
#   'kekebalan',
#   'tubuh',
#   'dan',
#   'keuntungan',
#   'tersebut',
#   'sudah',
#   'tentu',
#   'berlanjut',
#   'jika',
#   'hasrat',
#   'tersebut',
#   'direalisasikan'],
#  ['menurut',
#   'penelitian',
#   'saat',
#   'berhubungan',
#   'sex',
#   'kadar',
#   'hormon',
#   'oksitosin',
#   'akan',
#   'terlepas',
#   'bersamaan',
#   'dengan',
#   'orgasme'],
#  ['kita', 'menginginkan', 'pasangan', 'menjadi', 'sosok', 'yang', 'sempurna'],
#  ['tidak',
#   'peduli',
#   'seberapa',
#   'mengecewakannya',
#   'hubungan',
#   'yang',
#   'dijalani',
#   'pasti',
#   'akan',
#   'ada',
#   'masanya',
#   'anda',
#   'saling',
#   'merindukan'],
#  ['dengan',
#   'membubuhkan',
#   'tato',
#   'di',
#   'tubuh',
#   'anda',
#   'tentunya',
#   'akan',
#   'selalu',
#   'mengingatkan',
#   'dengan',
#   'mantan',
#   'dan',
#   'ini',
#   'bukanlah',
#   'ide',
#   'bagus',
#   'untuk',
#   'melanjutkan',
#   'hidup',
#   'dan',
#   'segera',
#   'mencari',
#   'penggantinya'],
#  ['duduk', 'di', 'tempat', 'tidur', 'selama', 'mnt'],
#  ['jalan',
#   'kaki',
#   'juga',
#   'bisa',
#   'menurunkan',
#   'risiko',
#   'terkena',
#   'kanker',
#   'payudara'],
#  ['semarang'],
#  ['sehingga',
#   'semakin',
#   'banyak',
#   'seseorang',
#   'merokok',
#   'semakin',
#   'tinggi',
#   'risiko',
#   'untuk',
#   'impotensi'],
#  ['saat',
#   'berhubungan',
#   'seks',
#   'tubuh',
#   'anda',
#   'memproduksi',
#   'dopamin',
#   'zat',
#   'yang',
#   'melawan',
#   'hormon',
#   'stres',
#   'endorfin',
#   'alias',
#   'hormon',
#   'kebahagiaan',
#   'dan',
#   'oksitosin',
#   'hormon',
#   'hasrat',
#   'birahi',
#   'yang',
#   'dikeluarkan',
#   'oleh',
#   'kelenjar',
#   'hipofisis'],
#  ['jack',
#   'vaisman',
#   'konsultan',
#   'medis',
#   'on',
#   'clinic',
#   'international',
#   'di',
#   'sydney',
#   'menekankan',
#   'jika',
#   'anda',
#   'mengalami',
#   'ejakulasi',
#   'dini',
#   'tidak',
#   'ada',
#   'cara',
#   'lain',
#   'agar',
#   'segera',
#   'berobat',
#   'ke',
#   'dokter'],
#  ['bina',
#   'cinta',
#   'anda',
#   'terdapat',
#   'banyak',
#   'sekali',
#   'teknik',
#   'yang',
#   'dilakukan',
#   'pasangan',
#   'untuk',
#   'membuat',
#   'anda',
#   'mengetahui',
#   'bahwa',
#   'dia',
#   'sangat',
#   'mencintai',
#   'anda',
#   'dan',
#   'demikian',
#   'juga',
#   'sebaliknya'],
#  ['jadi', 'harus', 'dilakukan', 'dengan', 'segera'],
#  ['sex',
#   'obat',
#   'penenang',
#   'yang',
#   'paling',
#   'aman',
#   'di',
#   'dunia',
#   'x',
#   'lebih',
#   'efektif',
#   'dari',
#   'valium'],
#  ['untuk',
#   'menjawab',
#   'kesulitan',
#   'ini',
#   'on',
#   'clinic',
#   'indonesia',
#   'saat',
#   'ini',
#   'sudah',
#   'menghadirkan',
#   'layanan',
#   'barunya',
#   'yaitu',
#   'divisi',
#   'stopro',
#   'untuk',
#   'membantu',
#   'orang',
#   'orang',
#   'yang',
#   'ingin',
#   'berhenti',
#   'merokok',
#   'segera'],
#  ['co'],
#  ['namun',
#   'beberapa',
#   'penelitian',
#   'belakangan',
#   'ini',
#   'telah',
#   'memberikan',
#   'hasil',
#   'yang',
#   'begitu',
#   'meyakinkan',
#   'bahwa',
#   'pria',
#   'lebih',
#   'muda',
#   'yang',
#   'nampak',
#   'bugar',
#   'pun',
#   'sangat',
#   'memungkinkan',
#   'menderita',
#   'gangguan',
#   'prostat'],
#  ['meski',
#   'demikian',
#   'ia',
#   'meyakinkan',
#   'tetap',
#   'dapat',
#   'disembuhkan',
#   'dengan',
#   'metode',
#   'pengobatan',
#   'yang',
#   'tepat',
#   'selain',
#   'misalnya',
#   'olah',
#   'raga',
#   'makan',
#   'makanan',
#   'yang',
#   'sehat',
#   'berhenti',
#   'merokok',
#   'dan',
#   'minuman',
#   'keras',
#   'tuturnya'],
#  ['menurut',
#   'penelitian',
#   'ada',
#   'jenis',
#   'penyakit',
#   'yg',
#   'bisa',
#   'disembuhkan',
#   'dengan',
#   'berolahraga',
#   'jalan',
#   'kaki',
#   'yang',
#   'teratur'],
#  ['bagi',
#   'pria',
#   'atau',
#   'dikenal',
#   'dengan',
#   'istilah',
#   'medis',
#   'sebagai',
#   'disfungsi',
#   'ereksi',
#   'merupakan',
#   'penyakit',
#   'paling',
#   'memalukan',
#   'dan',
#   'paling',
#   'menyedihkan'],
#  ['seks',
#   'mengurangi',
#   'stres',
#   'yang',
#   'merupakan',
#   'salah',
#   'satu',
#   'alasan',
#   'wanita',
#   'kehilangan',
#   'waktu',
#   'mereka'],
#  ['kondisi',
#   'seperti',
#   'ini',
#   'sebaiknya',
#   'tidak',
#   'boleh',
#   'dibiarkan',
#   'karena',
#   'bisa',
#   'semakin',
#   'buruk',
#   'bahkan',
#   'sampai',
#   'menyebabkan',
#   'kanker',
#   'prostat'],
#  ['pujilah',
#   'pasangan',
#   'pada',
#   'hal',
#   'hal',
#   'baik',
#   'yang',
#   'anda',
#   'suka',
#   'darinya',
#   'dan',
#   'abaikan',
#   'semua',
#   'hal',
#   'yang',
#   'mengganggu',
#   'dari',
#   'pasangan',
#   'anda'],
#  ['heart', 'attack', 'dapat', 'membunuh', 'tanpa', 'tanda', 'awal'],
#  ['periksa', 'sekarang', 'juga', 'lindungi', 'jantung', 'anda'],
#  ['pemeriksaan',
#   'ekg',
#   'merupakan',
#   'tindakan',
#   'prefentif',
#   'untuk',
#   'menghindari',
#   'heart',
#   'attack',
#   'yang',
#   'tidak',
#   'terduga'],
#  ['atau', 'sms', 'pin', 'bb', 'fd', 'f', 'f', 'www'],
#  ['dr'],
#  ['hal',
#   'ini',
#   'akan',
#   'membantu',
#   'tidur',
#   'anda',
#   'jadi',
#   'lebih',
#   'nyenyak'],
#  ['banyak',
#   'penelitian',
#   'membuktikan',
#   'bahan',
#   'bahan',
#   'kimia',
#   'dalam',
#   'setiap',
#   'hisapan',
#   'rokok',
#   'bisa',
#   'menyebabkan',
#   'atau',
#   'disfungsi',
#   'ereksi',
#   'de'],
#  ['biasanya',
#   'mantan',
#   'masih',
#   'dijadikan',
#   'tolak',
#   'ukur',
#   'saat',
#   'anda',
#   'akan',
#   'bertemu',
#   'calon',
#   'pasangan',
#   'lain'],
#  ['kebersihan',
#   'daerah',
#   'vital',
#   'memang',
#   'penting',
#   'bagi',
#   'pasangan',
#   'anda'],
#  ['memang',
#   'putusnya',
#   'hubungan',
#   'cinta',
#   'bukan',
#   'berarti',
#   'putus',
#   'komunikasi'],
#  ['bandung'],
#  ['onclinic'],
#  ['metode',
#   'pengobatan',
#   'seperti',
#   'di',
#   'bebas',
#   'beser',
#   'sudah',
#   'digunakan',
#   'disemua',
#   'jaringan',
#   'on',
#   'clinic',
#   'international',
#   'dibeberapa',
#   'negara',
#   'terutama',
#   'di',
#   'australia',
#   'selandia',
#   'baru',
#   'rusia',
#   'romania',
#   'seluruh',
#   'negara',
#   'eropa',
#   'timur',
#   'serta',
#   'philipina'],
#  ['selama',
#   'ini',
#   'masalah',
#   'gangguan',
#   'kelenjar',
#   'prostat',
#   'sering',
#   'disebut',
#   'sebagai',
#   'penyakit',
#   'usia'],
#  ['riset',
#   'membuktikan',
#   'bahwa',
#   'persen',
#   'pria',
#   'yang',
#   'mempraktrekkan',
#   'metode',
#   'ini',
#   'berhasil',
#   'mengontrol',
#   'ejakulasi',
#   'dalam',
#   'waktu',
#   'hingga',
#   'menit',
#   'atau',
#   'lebih'],
#  ['hal',
#   'ini',
#   'dapat',
#   'dilihat',
#   'dari',
#   'terus',
#   'meningkatnya',
#   'jumlah',
#   'penderita',
#   'penyakit',
#   'jantung'],
#  ['jack',
#   'vaisman',
#   'konsultan',
#   'medis',
#   'on',
#   'clinic',
#   'international',
#   'di',
#   'sydney',
#   'juga',
#   'menambahkan',
#   'tentu',
#   'masih',
#   'banyak',
#   'lagi',
#   'alasan',
#   'alasan',
#   'mengapa',
#   'anda',
#   'harus',
#   'berhubungan',
#   'sex',
#   'secara',
#   'rutin'],
#  ['hal',
#   'ini',
#   'juga',
#   'dipicu',
#   'oleh',
#   'faktor',
#   'kesenangan',
#   'yang',
#   'timbul',
#   'setelah',
#   'hubungan',
#   'seks'],
#  ['jaga',
#   'kebersihan',
#   'selama',
#   'menstruasi',
#   'hindari',
#   'menggunakan',
#   'pembalut',
#   'yang',
#   'berparfum',
#   'dan',
#   'mengangdung',
#   'bahan',
#   'kimi',
#   'lain',
#   'karena',
#   'dapat',
#   'menimbulkan',
#   'iritasi',
#   'dan',
#   'gatal',
#   'pada',
#   'vagina'],
#  ['dokter',
#   'membandingkan',
#   'dengan',
#   'ereksi',
#   'pada',
#   'refleks',
#   'atletik',
#   'semakin',
#   'anda',
#   'melatih',
#   'otot',
#   'tersebut',
#   'semakin',
#   'mampu',
#   'juga',
#   'anda',
#   'untuk',
#   'melakukan'],
#  ['jangan', 'kecewakan', 'pasangan', 'anda', 'dengan', 'tips', 'berikut'],
#  ['namun',
#   'jika',
#   'efeknya',
#   'sampai',
#   'pada',
#   'gangguan',
#   'ereksi',
#   'atau',
#   'impotensi',
#   'tidak',
#   'ada',
#   'pilihan',
#   'lain',
#   'kecuali',
#   'segera',
#   'berobat',
#   'ke',
#   'dokter',
#   'agar',
#   'hubungan',
#   'suami',
#   'istri',
#   'bisa',
#   'normal'],
#  ['seks',
#   'menghilangkan',
#   'stres',
#   'penelitian',
#   'menunjukkan',
#   'bahwa',
#   'seks',
#   'seperti',
#   'halnya',
#   'olahraga',
#   'dapat',
#   'mengurangi',
#   'bahkan',
#   'menghilangkan',
#   'kecemasan',
#   'menurunkan',
#   'hormon',
#   'stres',
#   'dan',
#   'dapat',
#   'membantu',
#   'orang',
#   'mengatasi',
#   'tekanan',
#   'mental',
#   'setidaknya',
#   'selama',
#   'satu',
#   'minggu',
#   'ke',
#   'depan'],
#  ['arah',
#   'siraman',
#   'air',
#   'harus',
#   'dari',
#   'arah',
#   'depan',
#   'yakni',
#   'vagina',
#   'ke',
#   'arah',
#   'anus'],
#  ['namun',
#   'jangan',
#   'sampai',
#   'perasaan',
#   'ini',
#   'berlarut',
#   'larut',
#   'sehingga',
#   'mengakibatkan',
#   'anda',
#   'melakukan',
#   'hal',
#   'hal',
#   'gila',
#   'yang',
#   'justru',
#   'membuat',
#   'tidak',
#   'bisa',
#   'melupakan',
#   'sang',
#   'mantan',
#   'dan',
#   'semua',
#   'kenangan',
#   'yang',
#   'telah',
#   'anda',
#   'lewati',
#   'bersama'],
#  ['d',
#   'seksolog',
#   'asal',
#   'los',
#   'angeles',
#   'dan',
#   'president',
#   'of',
#   'the',
#   'american',
#   'association',
#   'of',
#   'sexuality',
#   'educators',
#   'and',
#   'therapist',
#   'menyatakan',
#   'bahwa',
#   'sex',
#   'itu',
#   'model',
#   'latihan',
#   'yang',
#   'luar',
#   'biasa',
#   'karena',
#   'sangat',
#   'bagus',
#   'dari',
#   'sudut',
#   'pandang',
#   'jasmani',
#   'dan',
#   'rohani'],
#  ['beberapa',
#   'kewajiban',
#   'yang',
#   'mutlak',
#   'kita',
#   'laksanakan',
#   'agar',
#   'penyakit',
#   'jantung',
#   'tidak',
#   'mendekat',
#   'yaitu',
#   'makan',
#   'yang',
#   'bergizi',
#   'hindari',
#   'stres',
#   'olahraga',
#   'yang',
#   'teratur',
#   'istirahat',
#   'yang',
#   'cukup',
#   'dan',
#   'melakukan',
#   'pemeriksan',
#   'ekg',
#   'secara',
#   'dini'],
#  ['namun',
#   'rasa',
#   'rindu',
#   'yang',
#   'dirasakan',
#   'bukanlah',
#   'alasan',
#   'buat',
#   'anda',
#   'untuk',
#   'memulai',
#   'kembali',
#   'menjalin',
#   'komunikasi',
#   'dengan',
#   'mantan'],
#  ['sperma',
#   'sehat',
#   'jika',
#   'anda',
#   'mencoba',
#   'untuk',
#   'memiliki',
#   'keturunan',
#   'adalah',
#   'dengan',
#   'anda',
#   'meningkatkan',
#   'volume',
#   'air',
#   'mani',
#   'yang',
#   'masuk',
#   'saat',
#   'anda',
#   'melakukan',
#   'hubungan',
#   'seks',
#   'secara',
#   'teratur'],
#  ['lakukan',
#   'hobi',
#   'dan',
#   'kegiatan',
#   'positif',
#   'usahakan',
#   'jangan',
#   'sampai',
#   'ada',
#   'waktu',
#   'kosong',
#   'dalam',
#   'satu',
#   'hari',
#   'kecuali',
#   'untuk',
#   'istirahat',
#   'dan',
#   'tidur'],
#  ['on',
#   'clinic',
#   'indonesia',
#   'merupakan',
#   'jaringan',
#   'layanan',
#   'kesehatan',
#   'yang',
#   'dapat',
#   'mengatasi',
#   'problem',
#   'seksual',
#   'pria',
#   'yaitu',
#   'ejakulasi',
#   'dini',
#   'impotensi',
#   'serta',
#   'problem',
#   'seksual',
#   'perempuan',
#   'yang',
#   'mengalami',
#   'gangguan',
#   'orgasme',
#   'frigid',
#   'dan',
#   'kurang',
#   'gairah'],
#  ['co'],
#  ['atau', 'sms', 'pin', 'bb', 'fd', 'f', 'f', 'www'],
#  ['para',
#   'peneliti',
#   'di',
#   'national',
#   'cancer',
#   'institute',
#   'menganalisis',
#   'data',
#   'dan',
#   'menentukan',
#   'bahwa',
#   'kelompok',
#   'pria',
#   'yang',
#   'mengalami',
#   'orgasme',
#   'per',
#   'bulan',
#   'jauh',
#   'lebih',
#   'kecil',
#   'kemungkinannya',
#   'untuk',
#   'menderita',
#   'kanker',
#   'prostat',
#   'daripada',
#   'pria',
#   'yang',
#   'rata',
#   'rata',
#   'tujuh',
#   'kali',
#   'ejakulasi',
#   'per',
#   'bulan'],
#  ['tingkatkan', 'keterampilan', 'komunikasi', 'anda', 'dengan', 'pasangan'],
#  ['id'],
#  ['ada',
#   'baiknya',
#   'juga',
#   'untuk',
#   'lebih',
#   'sering',
#   'menghabiskan',
#   'waktu',
#   'bersama',
#   'dengan',
#   'teman',
#   'teman',
#   'dan',
#   'melakukan',
#   'berbagai',
#   'kegiatan',
#   'yang',
#   'anda',
#   'suka',
#   'bersama'],
#  ['pria',
#   'dari',
#   'tiongkok',
#   'usia',
#   'sekitar',
#   'tahun',
#   'ke',
#   'atas',
#   'yang',
#   'menghabiskan',
#   'batang',
#   'rokok',
#   'sehari',
#   'memiliki',
#   'risiko',
#   'terkena',
#   'impotensi',
#   'hingga',
#   'persen',
#   'dibandingkan',
#   'pria',
#   'yang',
#   'tidak',
#   'pernah',
#   'merokok'],
#  ['untuk',
#   'menghindari',
#   'ini',
#   'anda',
#   'tidak',
#   'punya',
#   'cara',
#   'untuk',
#   'mengobati',
#   'selain',
#   'menyerahkan',
#   'pada',
#   'ahlinya'],
#  ['sehingga',
#   'pengobatan',
#   'yang',
#   'dilakukan',
#   'pada',
#   'akhirnya',
#   'tidak',
#   'banyak',
#   'membantu',
#   'karena',
#   'kanker',
#   'sudah',
#   'masuk',
#   'ke',
#   'tahap',
#   'lanjut',
#   'hingga',
#   'mengalami',
#   'metastasis',
#   'atau',
#   'menyebar'],
#  ['sudah',
#   'jelas',
#   'bahwa',
#   'pemerintah',
#   'saja',
#   'mengumunkan',
#   'bahwa',
#   'semua',
#   'jenis',
#   'obat',
#   'kuat',
#   'yang',
#   'beredar',
#   'adalah',
#   'ilegal',
#   'dan',
#   'tidak',
#   'layak',
#   'konsumsi'],
#  ['itulah',
#   'perasaan',
#   'yang',
#   'biasanya',
#   'menghantui',
#   'kaum',
#   'pria',
#   'yang',
#   'mengeluh',
#   'menurut',
#   'prof'],
#  ['guna',
#   'memberikan',
#   'pengobatan',
#   'yang',
#   'tepat',
#   'untuk',
#   'pasien',
#   'pasien',
#   'yang',
#   'mengalami',
#   'inkontinensia',
#   'urin',
#   'beser',
#   'telah',
#   'hadir',
#   'bebas',
#   'beser',
#   'di',
#   'indonesia',
#   'untuk',
#   'membantu',
#   'mengatasi',
#   'gangguan',
#   'beser',
#   'dengan',
#   'pengobatan',
#   'yang',
#   'memberikan',
#   'tingkat',
#   'keberhasilan',
#   'yang',
#   'tinggi',
#   'dan',
#   'relatif',
#   'aman'],
#  ['diantara',
#   'banyak',
#   'hal',
#   'sex',
#   'merupakan',
#   'salah',
#   'satu',
#   'yang',
#   'terpenting',
#   'dalam',
#   'memperkokoh',
#   'pondasi',
#   'rumah',
#   'tangga'],
#  ['co'],
#  ['apakah', 'anda', 'mengalami', 'migrain', 'dan', 'nyeri', 'tubuh'],
#  ['nah', 'seks', 'jawabannya'],
#  ['healthylifemagz'],
#  ['perlu',
#   'waktu',
#   'dan',
#   'keikhlasan',
#   'untuk',
#   'bisa',
#   'benar',
#   'benar',
#   'mengusir',
#   'bayang',
#   'bayang',
#   'mantan',
#   'dari',
#   'hidup',
#   'kita'],
#  ['jika',
#   'anda',
#   'menemukan',
#   'seseorang',
#   'dengan',
#   'impotensi',
#   'hal',
#   'utama',
#   'yang',
#   'mesti',
#   'anda',
#   'lakukan',
#   'pertama',
#   'kali',
#   'adalah',
#   'memperbaiki',
#   'semua',
#   'masalah',
#   'kardiovaskular',
#   'yang',
#   'utamanya',
#   'yaitu',
#   'dengan',
#   'cara',
#   'berhenti',
#   'merokok',
#   'tegas',
#   'john',
#   'morley',
#   'direktur',
#   'kedokteran',
#   'geriatrik',
#   'di',
#   'st'],
#  ['walaupun',
#   'pada',
#   'kenyataannya',
#   'tidak',
#   'sedikit',
#   'kaum',
#   'pria',
#   'yang',
#   'mengalami',
#   'apa',
#   'yang',
#   'biasa',
#   'disebut',
#   'dengan',
#   'ejakulasi',
#   'dini',
#   'ini'],
#  ['secara',
#   'psikologis',
#   'ketidaknyamanan',
#   'saat',
#   'berkemih',
#   'ini',
#   'umumnya',
#   'akan',
#   'membuat',
#   'orang',
#   'risih',
#   'dan',
#   'akhirnya',
#   'malas',
#   'berhubungan',
#   'intim'],
#  ['beberapa',
#   'gejala',
#   'yang',
#   'perlu',
#   'anda',
#   'kuatirkan',
#   'karena',
#   'bisa',
#   'terkait',
#   'dengan',
#   'gangguanprostat',
#   'antara',
#   'lain',
#   'sering',
#   'atau',
#   'kebelet',
#   'buang',
#   'air',
#   'kecil',
#   'yang',
#   'mengganggu',
#   'tidur',
#   'buang',
#   'air',
#   'kecil',
#   'yang',
#   'tidak',
#   'tuntas',
#   'dan',
#   'urine',
#   'kurang',
#   'lancar',
#   'kandung',
#   'kemih',
#   'yang',
#   'tidak',
#   'terasa',
#   'kosong',
#   'setelah',
#   'buang',
#   'air',
#   'kecil',
#   'buang',
#   'air',
#   'kecil',
#   'setiap',
#   'kurang',
#   'dari',
#   'jam',
#   'kesulitan',
#   'mengeluarkan',
#   'urine',
#   'sewaktu',
#   'buang',
#   'air',
#   'kecil',
#   'dan',
#   'buang',
#   'air',
#   'kecil',
#   'lebih',
#   'dari',
#   'kali',
#   'di',
#   'malam',
#   'hari'],
#  ['kenangan',
#   'baik',
#   'maupun',
#   'pahit',
#   'bersama',
#   'mantan',
#   'pasangan',
#   'akan',
#   'menjadi',
#   'momen',
#   'yang',
#   'perlahan',
#   'akan',
#   'hilang',
#   'dari',
#   'kehidupanmu'],
#  ['dengan',
#   'membuat',
#   'tato',
#   'mantan',
#   'bukan',
#   'tidak',
#   'mungkin',
#   'justru',
#   'malah',
#   'menjadikan',
#   'dia',
#   'bayang',
#   'bayang',
#   'masa',
#   'lalu',
#   'yang',
#   'anda',
#   'ciptakan',
#   'sendiri'],
#  [],
#  ['buat',
#   'anda',
#   'yang',
#   'ingin',
#   'menjaga',
#   'berat',
#   'badan',
#   'tetap',
#   'ideal',
#   'aktivitas',
#   'sex',
#   'juga',
#   'merupakan',
#   'kiat',
#   'yang',
#   'sangat',
#   'tepat',
#   'selain',
#   'anda',
#   'juga',
#   'bisa',
#   'mendapatkan',
#   'manfaat',
#   'kardiovaskularnya'],
#  ['id'],
#  ['co'],
#  ['kata',
#   'orang',
#   'jatuh',
#   'cinta',
#   'itu',
#   'memang',
#   'berjuta',
#   'rasanya',
#   'akan',
#   'tetapi',
#   'putus',
#   'cinta',
#   'pun',
#   'tidak',
#   'kalah',
#   'menyakitkannya'],
#  ['yogyakarta'],
#  ['surabaya'],
#  ['on',
#   'clinic',
#   'indonesia',
#   'adalah',
#   'jaringan',
#   'klinik',
#   'yang',
#   'bisa',
#   'mengatasi',
#   'dengan',
#   'tingkat',
#   'keberhasilan',
#   'yang',
#   'sangat',
#   'tinggi'],
#  ['apalah',
#   'artinya',
#   'hubungan',
#   'seks',
#   'jika',
#   'tidak',
#   'disertai',
#   'orgasme',
#   'mahadahsyat',
#   'yang',
#   'juga',
#   'merupakan',
#   'hak',
#   'bagi',
#   'pasangan',
#   'anda'],
#  ['jangan',
#   'mengaku',
#   'pria',
#   'sejati',
#   'jika',
#   'memenuhi',
#   'kebutuhan',
#   'wanita',
#   'yang',
#   'paling',
#   'dasar',
#   'saja',
#   'tidak',
#   'anda',
#   'lakukan'],
#  ['sehingga',
#   'bukannya',
#   'masalah',
#   'tuntas',
#   'malah',
#   'mendatangkan',
#   'masalah',
#   'baru',
#   'buat',
#   'organ',
#   'organ',
#   'vital',
#   'lainnya'],
#  ['malang'],
#  ['mencegah',
#   'osteoporosis',
#   'osteoporosis',
#   'tdk',
#   'cukup',
#   'hanya',
#   'dengan',
#   'rutin',
#   'mengkonsumsi',
#   'vitamin',
#   'd',
#   'asupan',
#   'kalsium',
#   'yg',
#   'banyak',
#   'tubuh',
#   'juga',
#   'membutuhkan',
#   'gerak',
#   'badan',
#   'memerlukan',
#   'waktu',
#   'paling',
#   'kurang',
#   'menit',
#   'dibawah',
#   'sinar',
#   'matahari',
#   'pagi',
#   'anda',
#   'akan',
#   'terhindar',
#   'dr',
#   'osteoporosis'],
#  ['balikpapan'],
#  ['sayangnya',
#   'merokok',
#   'memberikan',
#   'kontribusi',
#   'untuk',
#   'terjadinya',
#   'penumpukan',
#   'plak',
#   'di',
#   'arteri',
#   'yang',
#   'dapat',
#   'membatasi',
#   'aliran',
#   'darah',
#   'ke',
#   'penis'],
#  ['prostate',
#   'health',
#   'merupakan',
#   'divisi',
#   'on',
#   'clinic',
#   'indonesia',
#   'yang',
#   'dapat',
#   'mengatasi',
#   'gangguan',
#   'prostat',
#   'dengan',
#   'pengobatan',
#   'yang',
#   'memberikan',
#   'tingkat',
#   'keberhasilan',
#   'yang',
#   'tinggi',
#   'dan',
#   'relatif',
#   'aman',
#   'karena',
#   'sediaannya',
#   'yang',
#   'alami'],
#  ['r'],
#  ['anda',
#   'pasti',
#   'menyadari',
#   'bahwa',
#   'tingkat',
#   'pernapasan',
#   'meningkat',
#   'yang',
#   'berarti',
#   'anda',
#   'mulai',
#   'kelelahan'],
#  ['membakar',
#   'kalori',
#   'seorang',
#   'pria',
#   'akan',
#   'membakar',
#   'sekitar',
#   'kalori',
#   'dalam',
#   'satu',
#   'jam',
#   'aktivitas',
#   'seksual',
#   'yang',
#   'intens'],
#  ['terlebih',
#   'dengan',
#   'kemajuan',
#   'teknologi',
#   'dan',
#   'tingkat',
#   'persaingan',
#   'yang',
#   'tinggi',
#   'untuk',
#   'bertahan',
#   'hidup',
#   'membuat',
#   'depresi',
#   'dan',
#   'stress',
#   'semakin',
#   'menekan',
#   'dan',
#   'berakhir',
#   'dengan',
#   'ketidakmampuan',
#   'dalam',
#   'mempertahankan',
#   'ereksi',
#   'lebih',
#   'lama',
#   'atau'],
#  ['berdasarkan',
#   'pengalaman',
#   'klinis',
#   'perbaikan',
#   'mulai',
#   'terlihat',
#   'setelah',
#   'penggunaan',
#   'minggu',
#   'tetapi',
#   'akan',
#   'tuntas',
#   'dalam',
#   'pengobatan',
#   'bulan'],
#  ['yang',
#   'pasti',
#   'semuanya',
#   'bisa',
#   'anda',
#   'dapatkan',
#   'hanya',
#   'jika',
#   'tubuh',
#   'anda',
#   'memiliki',
#   'fungsi',
#   'seksual',
#   'yang',
#   'optimal'],
#  ['pengobatan',
#   'di',
#   'stopro',
#   'memberikan',
#   'tingkat',
#   'keberhasilan',
#   'yang',
#   'tinggi',
#   'dan',
#   'relatif',
#   'aman',
#   'karena',
#   'sediaannya',
#   'yang',
#   'herbal',
#   'non',
#   'nikotin',
#   'alami'],
#  ['semoga', 'bermanfaat', 'selamat', 'berkarya'],
#  ['meningkatkan',
#   'kesehatan',
#   'jantung',
#   'sebuah',
#   'studi',
#   'di',
#   'american',
#   'journal',
#   'of',
#   'cardiology',
#   'menunjukkan',
#   'bahwa',
#   'pria',
#   'yang',
#   'berhubungan',
#   'seks',
#   'dua',
#   'kali',
#   'seminggu',
#   'memiliki',
#   'risiko',
#   'lebih',
#   'rendah',
#   'dari',
#   'penyakit',
#   'kardiovaskular',
#   'jantung',
#   'daripada',
#   'pria',
#   'yang',
#   'jarang',
#   'sekali',
#   'melakukan',
#   'hubungan',
#   'seks'],
#  ['studi',
#   'ini',
#   'menyimpulkan',
#   'bahwa',
#   'laki',
#   'laki',
#   'memiliki',
#   'resiko',
#   'persen',
#   'lebih',
#   'rendah',
#   'untuk',
#   'mengalami',
#   'penyakit',
#   'kardiovaskular'],
#  ['setidaknya',
#   'merasa',
#   'tak',
#   'enak',
#   'hati',
#   'atau',
#   'malah',
#   'malu',
#   'pada',
#   'istri',
#   'bila',
#   'harus',
#   'mondar',
#   'mandir',
#   'ke',
#   'kamar',
#   'mandi',
#   'hingga',
#   'sama',
#   'sekali',
#   'tak',
#   'bisa',
#   'menikmati',
#   'hubungan'],
#  ['secara',
#   'umum',
#   'pria',
#   'merokok',
#   'persen',
#   'lebih',
#   'rentan',
#   'terkena',
#   'impotensi',
#   'ketimbang',
#   'yang',
#   'bukan',
#   'perokok'],
#  ['namun', 'bukan', 'berarti', 'cepat', 'itu', 'segala', 'galanya'],
#  ['dirinya',
#   'semakin',
#   'terpuruk',
#   'seiring',
#   'dengan',
#   'situasi',
#   'rumah',
#   'tangganya',
#   'yang',
#   'terancam',
#   'bubar',
#   'akibat',
#   'pasangan',
#   'yang',
#   'kerap',
#   'uring',
#   'uringan',
#   'tidak',
#   'jelas'],
#  ['durex'],
#  [],
#  ['dengan',
#   'panduan',
#   'dari',
#   'tim',
#   'ahli',
#   'medis',
#   'berpengalaman',
#   'pengobatan',
#   'di',
#   'stopro',
#   'sangat',
#   'efektif',
#   'sehingga',
#   'pasien',
#   'bisa',
#   'bebas',
#   'dari',
#   'rokok',
#   'dalam',
#   'waktu',
#   'yang',
#   'singkat'],
#  ['namun',
#   'jika',
#   'permasalahaanya',
#   'lebih',
#   'kompleks',
#   'yang',
#   'berasal',
#   'dari',
#   'faktor',
#   'fisik',
#   'tentu',
#   'tidak',
#   'ada',
#   'cara',
#   'lain',
#   'untuk',
#   'selain',
#   'mengunjungi',
#   'dokter',
#   'ahlinya'],
#  [],
#  ['jika',
#   'terjadinya',
#   'sekali',
#   'dua',
#   'kali',
#   'saja',
#   'mungkin',
#   'masih',
#   'bisa',
#   'dianggap',
#   'wajar'],
#  ['sedikit',
#   'gangguan',
#   'saja',
#   'berarti',
#   'kesehatan',
#   'anda',
#   'bakal',
#   'terancam'],
#  ['id',
#   'explore',
#   'sex',
#   'artikel',
#   'kesehatan',
#   'manfaat',
#   'seks',
#   'untuk',
#   'kesehatan'],
#  ['seks',
#   'tampaknya',
#   'seperti',
#   'pilihan',
#   'yang',
#   'lebih',
#   'baik',
#   'daripada',
#   'obat',
#   'obatan'],
#  ['pria',
#   'dari',
#   'china',
#   'usia',
#   'sekitar',
#   'tahun',
#   'ke',
#   'atas',
#   'yang',
#   'menghabiskan',
#   'batang',
#   'rokok',
#   'sehari',
#   'memiliki',
#   'risiko',
#   'terkena',
#   'hingga',
#   'persen',
#   'dibandingkan',
#   'pria',
#   'yang',
#   'tidak',
#   'pernah',
#   'merokok'],
#  ['tapi', 'coba', 'tebak'],
#  ['seks', 'bekerja', 'dengan', 'cara', 'yang', 'sama', 'seperti', 'olahraga'],
#  ['kanker',
#   'bergerak',
#   'badan',
#   'ikut',
#   'melancarkan',
#   'peristaltik',
#   'usus',
#   'sehingga',
#   'buang',
#   'air',
#   'besar',
#   'lebih',
#   'tertib'],
#  ['seks',
#   'mengatur',
#   'hormon',
#   'yang',
#   'pada',
#   'gilirannya',
#   'mengatur',
#   'siklus',
#   'menstruasi'],
#  ['siklus',
#   'menstruasi',
#   'ternyata',
#   'seks',
#   'dapat',
#   'meningkatkan',
#   'siklus',
#   'menstruasi',
#   'anda'],
#  ['semua',
#   'organ',
#   'penting',
#   'tubuh',
#   'patut',
#   'dijaga',
#   'karena',
#   'masing',
#   'masing',
#   'dari',
#   'mereka',
#   'memiliki',
#   'fungsi',
#   'penting',
#   'bagi',
#   'tubuh',
#   'kita'],
#  ['hal',
#   'bertujuan',
#   'untuk',
#   'mengurangi',
#   'penyebaran',
#   'infeksi',
#   'ke',
#   'daerah',
#   'lain'],
#  ['semoga', 'bermanfaat', 'silakan', 'mencoba'],
#  ['dapatkan',
#   'info',
#   'menarik',
#   'seputar',
#   'kesehatan',
#   'gaya',
#   'hidup',
#   'sehat',
#   'di',
#   'www'],
#  ['berikut',
#   'ini',
#   'beberapa',
#   'hal',
#   'yang',
#   'harus',
#   'dihindari',
#   'setelah',
#   'anda',
#   'memutuskan',
#   'untuk',
#   'mengakhiri',
#   'hubungan',
#   'asmara',
#   'dengan',
#   'pasangan'],
#  ['orang',
#   'kadang',
#   'kadang',
#   'kehilangan',
#   'individualitas',
#   'setelah',
#   'mereka',
#   'memiliki',
#   'anak'],
#  ['orang',
#   'usia',
#   'diminta',
#   'untuk',
#   'melakukan',
#   'hubungan',
#   'seksual',
#   'dan',
#   'masturbasi',
#   'antara',
#   'usia',
#   'dan'],
#  [],
#  ['denpasar'],
#  ['dalam',
#   'sebuah',
#   'penelitian',
#   'di',
#   'australia',
#   'pria',
#   'yang',
#   'berejakulasi',
#   'kali',
#   'dalam',
#   'sebulan',
#   'merupakan',
#   'pria',
#   'yang',
#   'kecil',
#   'kemungkinannya',
#   'mengidap',
#   'kanker'],
#  ['jika',
#   'ada',
#   'tidak',
#   'membangun',
#   'alami',
#   'sperma',
#   'anda',
#   'dapat',
#   'terjadi',
#   'kerusakan',
#   'dna'],
#  ['sosok',
#   'terbaik',
#   'ada',
#   'baiknya',
#   'anda',
#   'selalu',
#   'berupaya',
#   'untuk',
#   'menemukan',
#   'sosok',
#   'terbaik',
#   'dari',
#   'pasangan',
#   'daripada',
#   'mengubah',
#   'kebiasaan',
#   'jeleknya'],
#  ['selain',
#   'dibutuhkan',
#   'niat',
#   'yang',
#   'kuat',
#   'untuk',
#   'berhenti',
#   'seorang',
#   'perokok',
#   'juga',
#   'perlu',
#   'motivasi',
#   'dan',
#   'informasi',
#   'sehingga',
#   'seseorang',
#   'yang',
#   'tadinya',
#   'mungkin',
#   'tidak',
#   'paham',
#   'dengan',
#   'bahaya',
#   'rokok',
#   'menjadi',
#   'lebih',
#   'mengerti',
#   'dan',
#   'dapat',
#   'menghentikan',
#   'kebiasaan',
#   'buruknya',
#   'sebelum',
#   'diserang',
#   'penyakit'],
#  ['padahal',
#   'ada',
#   'cara',
#   'lain',
#   'yang',
#   'mungkin',
#   'belum',
#   'terbayangkan',
#   'namun',
#   'dijamin',
#   'jauh',
#   'lebih',
#   'menyenangkan',
#   'untuk',
#   'mendapatkan',
#   'tubuh',
#   'yang',
#   'sehat'],
#  ['seks', 'teratur', 'menggantikan', 'sperma', 'lama', 'dari', 'testis'],
#  ['pekanbaru'],
#  ['belajarlah',
#   'untuk',
#   'menerima',
#   'kenyataan',
#   'bahwa',
#   'anda',
#   'dan',
#   'dia',
#   'sudah',
#   'tidak',
#   'bisa',
#   'berhubungan',
#   'dan',
#   'bersama',
#   'sama',
#   'lagi'],
#  ['dr', 'george', 'e'],
#  ['menyembuhkan',
#   'luka',
#   'lebih',
#   'cepat',
#   'percaya',
#   'atau',
#   'tidak',
#   'hasil',
#   'penelitian',
#   'membuktikan',
#   'bahwa',
#   'aktivitas',
#   'hubungan',
#   'seks',
#   'yang',
#   'sehat',
#   'dapat',
#   'menyembuhkan',
#   'luka',
#   'dua',
#   'kali',
#   'lebih',
#   'cepat',
#   'dari',
#   'pada',
#   'biasanya'],
#  ['penelitian',
#   'membuktikan',
#   'bahwa',
#   'seks',
#   'sangat',
#   'baik',
#   'untuk',
#   'kesehatan',
#   'intensitas',
#   'hubungan',
#   'seks',
#   'mungkin',
#   'bisa',
#   'menjadi',
#   'penanda',
#   'bagi',
#   'kesehatan',
#   'seseorang',
#   'secara',
#   'keseluruhan'],
#  ['email', 'heart'],
#  ['hal',
#   'ini',
#   'tentunya',
#   'akan',
#   'membuat',
#   'usaha',
#   'anda',
#   'untuk',
#   'jauh',
#   'lebih',
#   'mudah'],
#  ['cara', 'itu', 'adalah', 'berhubungan', 'sex', 'rutin'],
#  ['tetapi',
#   'jika',
#   'terlalu',
#   'sering',
#   'itu',
#   'lain',
#   'cerita',
#   'mengingat',
#   'seks',
#   'adalah',
#   'hubungan',
#   'mutualis',
#   'yang',
#   'sudah',
#   'seharusnya',
#   'dinikmati',
#   'bersama',
#   'hingga',
#   'akhir'],
#  ['mengingat',
#   'kelenjar',
#   'yang',
#   'hanya',
#   'dimiliki',
#   'oleh',
#   'kaum',
#   'pria',
#   'ini',
#   'secara',
#   'langsung',
#   'berpengaruh',
#   'terhadap',
#   'kualitas',
#   'kehidupan',
#   'seksual',
#   'sehingga',
#   'bisa',
#   'diasumsikan',
#   'bahwa',
#   'ini',
#   'merupakan',
#   'ancaman',
#   'nyata',
#   'bagi',
#   'anda',
#   'yang',
#   'selalu',
#   'ingin',
#   'tampil',
#   'prima',
#   'layaknya',
#   'pria',
#   'sejati'],
#  ['pilih',
#   'pelumas',
#   'berbahan',
#   'air',
#   'jangan',
#   'gunakan',
#   'jelly',
#   'petroleum',
#   'dan',
#   'minyak',
#   'berparfum',
#   'sebagai',
#   'pelumas'],
#  ['para',
#   'remaja',
#   'sebaiknya',
#   'juga',
#   'berpikir',
#   'ulang',
#   'jika',
#   'mereka',
#   'terus',
#   'merokok',
#   'efek',
#   'perusakan',
#   'dalam',
#   'tubuh',
#   'akan',
#   'terus',
#   'berlanjut',
#   'dan',
#   'semakin',
#   'parah',
#   'saat',
#   'mereka',
#   'dewasa'],
#  ['mengapa', 'perlu', 'x', 'menit'],
#  ['karena',
#   'pola',
#   'ecg',
#   'electro',
#   'cardiogram',
#   'seseorang',
#   'normal',
#   'pada',
#   'siang',
#   'hari',
#   'tetapi',
#   'bangun',
#   'tengah',
#   'malam',
#   'untuk',
#   'melaksanakan',
#   'hajat',
#   'tiba',
#   'pola',
#   'ecg',
#   'itu',
#   'dpt',
#   'berubah'],
#  ['ingat',
#   'setiap',
#   'orang',
#   'pasti',
#   'memiliki',
#   'kelebihan',
#   'dan',
#   'kekurangan',
#   'masing',
#   'masing'],
#  ['pekanbaru'],
#  ['para',
#   'ilmuwan',
#   'dair',
#   'wilkes',
#   'university',
#   'pennsylvania',
#   'as',
#   'menemukan',
#   'bukti',
#   'bahwa',
#   'mereka',
#   'yang',
#   'rutin',
#   'bercinta',
#   'seminggu',
#   'sekali',
#   'atau',
#   'lebih',
#   'memiliki',
#   'daya',
#   'tahan',
#   'yang',
#   'lebih',
#   'tinggi',
#   'ketimbang',
#   'mereka',
#   'yang',
#   'hanya',
#   'dua',
#   'minggu',
#   'sekali'],
#  ['tentu',
#   'yang',
#   'namanya',
#   'itu',
#   'paling',
#   'memalukan',
#   'dan',
#   'menyedihkan',
#   'buat',
#   'pria'],
#  ['kenyataannya',
#   'sangat',
#   'mudah',
#   'hanya',
#   'jika',
#   'ditangani',
#   'dengan',
#   'tepat'],
#  ['prof'],
#  ['selain',
#   'itu',
#   'sangat',
#   'dianjurkan',
#   'untuk',
#   'tidak',
#   'saling',
#   'menyalahkan',
#   'dalam',
#   'kehidupan',
#   'sehari',
#   'hari'],
#  ['ejakulasi',
#   'secara',
#   'teratur',
#   'akan',
#   'membuang',
#   'cairan',
#   'tersebut',
#   'keluar',
#   'dan',
#   'menjamin',
#   'kesejahteraan',
#   'prostat',
#   'anda',
#   'sampai',
#   'usia',
#   'tua'],
#  ['dan',
#   'yang',
#   'tidak',
#   'kalah',
#   'penting',
#   'di',
#   'on',
#   'clinic',
#   'kerahasiaan',
#   'pasien',
#   'menjadi',
#   'salah',
#   'satu',
#   'hal',
#   'yang',
#   'sangat',
#   'diperhatikan'],
#  ['catatan',
#   'redaksi',
#   'senam',
#   'lidah',
#   'mencegah',
#   'alzheimer',
#   'ada',
#   'dasarnya',
#   'dari',
#   'penelitian',
#   'ilmu',
#   'kedokteran',
#   'syaraf',
#   'lidah',
#   'berhubungan',
#   'dengan',
#   'otak',
#   'besar',
#   'saat',
#   'badan',
#   'kita',
#   'menjadi',
#   'tua',
#   'dan',
#   'lemah',
#   'tanda',
#   'yang',
#   'muncul',
#   'terlebih',
#   'dahulu',
#   'adalah',
#   'lidah',
#   'menjadi',
#   'kaku'],
#  ['mengurangi',
#   'nyeri',
#   'kesenangan',
#   'adalah',
#   'suatu',
#   'cara',
#   'untuk',
#   'mengalahkan',
#   'rasa',
#   'sakit'],
#  ['bagaimana', 'caranya'],
#  ['cegah',
#   'serangan',
#   'jantung',
#   'dengan',
#   'memperbaiki',
#   'pola',
#   'hidup',
#   'menjadi',
#   'lebih',
#   'sehat'],
#  ['jika',
#   'anda',
#   'berhenti',
#   'ejakulasi',
#   'cairan',
#   'tetap',
#   'berproduksi',
#   'dalam',
#   'kelenjar',
#   'tersebut',
#   'yang',
#   'cenderung',
#   'membengkak',
#   'menyebabkan',
#   'banyak',
#   'masalah'],
#  ['meski', 'demikian', 'kita', 'tak', 'perlu', 'takut', 'akan', 'hal', 'ini'],
#  [],
#  [],
#  ['komunikasi',
#   'usahakan',
#   'untuk',
#   'selalu',
#   'berdiskusi',
#   'dan',
#   'mengomunikasikan',
#   'segala',
#   'sesuatunya',
#   'dengan',
#   'pasangan'],
#  ['celana',
#   'dalam',
#   'katun',
#   'katun',
#   'merupakan',
#   'bahan',
#   'yang',
#   'cocok',
#   'dengan',
#   'semua',
#   'jenis',
#   'kulit'],
#  ['melalui',
#   'seks',
#   'teratur',
#   'anda',
#   'juga',
#   'dapat',
#   'menjaga',
#   'kandung',
#   'kemih',
#   'dan',
#   'fungsi',
#   'usus',
#   'yang',
#   'lebih',
#   'baik'],
#  ['bagaimana',
#   'tidak',
#   'mengingat',
#   'manfaat',
#   'terbesar',
#   'dalam',
#   'hubungan',
#   'sex',
#   'adalah',
#   'menurunkan',
#   'tekanan',
#   'darah',
#   'dan',
#   'meredam',
#   'stres'],
#  ['baik',
#   'bagi',
#   'anda',
#   'untuk',
#   'memiliki',
#   'seks',
#   'yang',
#   'baik',
#   'kata',
#   'david',
#   'weeks',
#   'seorang',
#   'neuropsikolog',
#   'klinis',
#   'di',
#   'rumah',
#   'sakit',
#   'royal',
#   'edinburgh',
#   'yang',
#   'melakukan',
#   'studi',
#   'tentang',
#   'efek',
#   'dari',
# ...
#  ['jilboobs', 'cantik', 'sange', 'masturbasi', 'part'],
#  ['ngentot', 'istri', 'semok', 'berjilbab'],
#  ['video', 'bokep', 'cewek', 'abg', 'jepang'],
#  ['bokep', 'cewek', 'igo', 'suka', 'nyepong', 'kontol'],
#  ['ketahuan', 'nonton', 'bokep', 'malah', 'diajak', 'ngentot'],
#  ['cewek', 'cantik', 'bugil', 'depan', 'kamera'],
#  ['tante', 'girang', 'di', 'seruduk', 'kontol', 'brondong'],
#  ['desahan', 'seks', 'dari', 'tante', 'girang', 'amoy', 'china'],
#  ['video', 'rekaman', 'janda', 'kembang', 'desa', 'lagi', 'mandi'],
#  ['video', 'bugil', 'model', 'ruby'],
#  ['bokep', 'streaming', 'tante', 'berjilbab', 'sange'],
#  ['pacar', 'pake', 'baju', 'hello', 'kitty'],
#  ['ngentotin', 'cewek', 'toge', 'tipe', 'bodi', 'idaman', 'kaum', 'lelaki'],
#  ['enak', 'banget', 'dogy', 'istri', 'bokong', 'bohai'],
#  ['selingkuhan', 'berjilbab', 'bantuin', 'cowoknya', 'keluarin', 'pejuh'],
#  ['ini', 'cewek', 'pasrah', 'aja', 'kapan', 'mau', 'dientot'],
#  ['siswi', 'cantik', 'nafsu', 'sama', 'gurunya'],
#  ['uang', 'dulu', 'kalau', 'mau', 'ngentot'],
#  ['anak', 'majikan', 'minta', 'diajarin', 'ngentot'],
#  ['video', 'kimcil', 'geng', 'motor', 'ngentot'],
#  ['cewek', 'korea', 'cantik', 'di', 'entot', 'dari', 'belakang'],
#  ['video', 'istri', 'isep', 'kontol', 'suami'],
#  ['sensasi', 'ngentot', 'kontol', 'besar', 'dan', 'panjang'],
#  ['expresi', 'cewek', 'abg', 'pulang', 'sekolah', 'langsung', 'ngentot'],
#  ['bangun', 'pagi', 'langsung', 'disepongin', 'istri', 'tercinta'],
#  ['tante', 'girang', 'mabuk', 'berondong'],
#  ['guru', 'cabul', 'suruh', 'siswi', 'buka', 'baju', 'terus', 'digenjot'],
#  ['video', 'ngentot', 'abg', 'cantik'],
#  ['cowonya', 'galak', 'nih'],
#  ['bokep', 'jepang', 'terbaru'],
#  ['cewek', 'berjilbab', 'binal', 'yang', 'suka', 'main', 'zakar'],
#  ['desahan', 'seks', 'dari', 'tante', 'girang', 'amoy', 'china'],
#  ['video', 'cewek', 'diperkosa'],
#  ['live', 'sepongan', 'tante', 'girang', 'nan', 'nikmat'],
#  ['video', 'bugil', 'abg', 'kaya', 'anak', 'pejabat'],
#  ['tante', 'nakal', 'montok', 'ngentot', 'sama', 'suami'],
#  ['video', 'ngentot', 'abg', 'cantik'],
#  ['anak', 'sma', 'chubby', 'masturbasi'],
#  ['video', 'bokep', 'cewek', 'bule', 'ngentot', 'di', 'mobil'],
#  ['si', 'manja', 'isep', 'lagi', 'kontol'],
#  ['tante', 'jilboobs', 'selingkuh', 'di', 'rekam'],
#  ['kelakuan', 'dokter', 'sange', 'ini', 'sungguh', 'terlalu'],
#  ['ngentot', 'dengan', 'janda', 'memek', 'tembam'],
#  ['ngedoggy', 'step', 'sister', 'yang', 'lagi', 'telponan', 'sama', 'pacar'],
#  ['cewek', 'binal', 'bugil', 'dan', 'masturbasi', 'di', 'tempat', 'rekreasi'],
#  ['ngentot', 'di', 'pinggir', 'pantai'],
#  ['muasin', 'tante', 'viona'],
#  ['cewek', 'panggilan', 'khusus', 'surabaya'],
#  ['abg', 'cantik', 'pasrah', 'saat', 'di', 'entot', 'om', 'om'],
#  ['pacar', 'berjilbab', 'nyepong', 'kontol', 'di', 'mobil'],
#  ['janda',
#   'cantik',
#   'suka',
#   'memanjakan',
#   'kekasihnya',
#   'di',
#   'atas',
#   'ranjang'],
#  ['toge', 'keenakan', 'di', 'gilir'],
#  ['pagi', 'pagi', 'ngentot', 'di', 'dapur'],
#  ['video',
#   'bokep',
#   'asian',
#   'sex',
#   'dairy',
#   'filipina',
#   'si',
#   'cewek',
#   'toket',
#   'gede'],
#  ['cewek', 'toket', 'gede', 'yang', 'jarang', 'di', 'jamah'],
#  ['melayu', 'sedap'],
#  ['pembantu', 'cantik', 'horny', 'didepan', 'webcam'],
#  ['cewek', 'berjilbab', 'gila', 'dance', 'bugil'],
#  ['cewenya', 'ketahuan', 'mencuri', 'malah', 'dientot'],
#  ['video', 'cewek', 'abg', 'pecah', 'perawan'],
#  ['video', 'ngentot', 'bocah', 'sma'],
#  ['ngintip', 'teman', 'kontakan', 'sebelah'],
#  ['video', 'siswi', 'manado', 'masturbasi', 'di', 'kamar'],
#  ['ngentot', 'memek', 'cewek', 'kampung'],
#  ['ngintip', 'jablay', 'pantura', 'layanin', 'tamu'],
#  ['di', 'wot', 'sama', 'kakak', 'spg'],
#  ['disepongon', 'cewek', 'berjilbab', 'hitam'],
#  ['jilboobs', 'sange', 'masturbasi', 'edisi', 'bu', 'guru', 'part'],
#  ['video', 'abg', 'montok', 'berwajah', 'imut', 'bugil', 'pamer', 'bodi'],
#  ['tante', 'jilbob', 'keenakan', 'di', 'genjot'],
#  ['video', 'bokep', 'misshijabhyper', 'project'],
#  ['kontol', 'bule', 'hantam', 'memek', 'melayu'],
#  ['pacar', 'imut', 'keenakan', 'ngentot'],
#  ['sepong', 'terus', 'sayang'],
#  ['video', 'ngentot', 'cewek', 'kembar'],
#  ['abg', 'sma', 'imut', 'masturbasi'],
#  ['ngentot', 'pacar', 'seksi', 'sambil', 'direkam', 'teman'],
#  ['nungging', 'dikit', 'trus', 'di', 'sodok', 'di', 'toilet'],
#  ['video', 'mesum', 'pelajar', 'sma', 'di', 'hutan'],
#  ['guru', 'bejat', 'ngentot', 'muridnya', 'seharian'],
#  ['cewek', 'filipina', 'di', 'boking', 'maen', 'bokep'],
#  ['ngentot', 'pacar', 'sangek', 'dikamarnya'],
#  ['cewek', 'abg', 'di', 'bayar', 'buat', 'ngentot', 'bareng', 'pacar'],
#  ['video', 'mesum', 'cewek', 'sma', 'berjilbab'],
#  ['jilbaber', 'cantik', 'lagi', 'nyepong', 'dalam', 'mobil'],
#  ['video', 'bokep', 'tante', 'mira', 'jablai', 'sangean'],
#  ['ria', 'sakurai', 'ngentot', 'sampai', 'becek'],
#  ['anak', 'tiri', 'dan', 'ayah', 'tiri'],
#  ['video', 'bokep', 'jadul', 'yg', 'tetap', 'eksis'],
#  ['japan', 'teen', 'pasrah', 'memeknya', 'di', 'mainin'],
#  ['cheating', 'asian', 'wife', 'banged', 'in', 'a', 'wet', 'session'],
#  ['hari', 'tanpa', 'pakaian', 'disekolah', 'berakhir', 'ngentot'],
#  ['ngentot', 'istri', 'bohai', 'sambil', 'masak'],
#  ['bokep', 'arabsexeposed', 'part'],
#  ['nina', 'suka', 'nyepong', 'sambil', 'mainin', 'memek', 'baru', 'ngentot'],
#  ['video', 'bugil', 'abg', 'kaya', 'anak', 'pejabat'],
#  ['ngentot', 'karyawati', 'body', 'aduhai'],
#  ['pacarku', 'yang', 'cantik', 'mulus'],
#  ['video', 'cewek', 'pecah', 'perawan'],
#  ['janda', 'kehausan'],
#  ['bokep', 'salam', 'pramuka', 'bokep', 'jilbab', 'sma'],
#  ['mainan', 'memek', 'sendiri', 'saat', 'macet'],
#  ['video', 'cewek', 'sma', 'bugil'],
#  ['ngentot', 'istri', 'bohai', 'di', 'atas', 'meja', 'makan'],
#  ['mia', 'khalifa', 'ngentot', 'sama', 'fansnya'],
#  ['film', 'bokep', 'semi', 'thailand', 'jan', 'dara'],
#  ['video', 'ngentot', 'cewek', 'panti', 'pijat'],
#  ['stepdad', 'mainin', 'remot', 'bergetar', 'di', 'memek', 'anak', 'tiri'],
#  ['siska', 'jago', 'nyepong'],
#  ['ngentot', 'dengan', 'cewek', 'cantik', 'toge', 'dalam', 'sauna'],
#  ['tante', 'semok', 'haus', 'kontol', 'gede'],
#  ['video',
#   'janda',
#   'muda',
#   'narsis',
#   'bugil',
#   'di',
#   'depan',
#   'kamera',
#   'buat',
#   'pamer',
#   'toket'],
#  ['video', 'bugil', 'wahyuni', 'solo'],
#  ['video', 'skandal', 'artis', 'asia', 'dari', 'thailand'],
#  ['disuruh', 'pakai', 'kondom', 'sama', 'abg', 'chubby'],
#  ['disepong', 'sama', 'gadis', 'cantik', 'berambut', 'pendek'],
#  ['video', 'bokep', 'tukaran', 'istri'],
#  ['cewek', 'cina', 'masturbasi', 'dalam', 'kamar', 'tidur'],
#  ['mia', 'khalifa', 'ngentot', 'di', 'kolam', 'renang'],
#  ['kelakuan', 'abg', 'mandi', 'yang', 'menyebabkan', 'handphone', 'rusak'],
#  ['semakin', 'dalam', 'semakin', 'nikmat'],
#  ['scandal', 'cewek', 'perawan', 'ngentot'],
#  ['memek', 'janda', 'toge', 'semok', 'creampie'],
#  ['bule', 'cantik', 'sange', 'ngocok', 'memek'],
#  ['bispak', 'abg', 'yang', 'suka', 'nungging'],
#  ['istriku', 'horny', 'banget'],
#  ['janda', 'rasa', 'perawan'],
#  ['video', 'tante', 'yang', 'lagi', 'horny', 'pengen', 'dipuasin'],
#  ['ngentot', 'cewek', 'jembut', 'tebal', 'sampai', 'crot'],
#  ['cewek', 'cantik', 'dipkasa', 'mesum', 'di', 'bigo', 'live', 'hot'],
#  ['artis', 'bokep', 'lesbian', 'realitykings', 'lagi', 'beraksi'],
#  ['video', 'bokep', 'jepang', 'memek', 'sempit'],
#  ['video', 'lucah', 'nita', 'nur', 'aisiyah'],
#  ['video', 'model', 'indo', 'serlyana', 'r'],
#  ['video', 'bugil', 'erissa'],
#  ['ngentot', 'ditempat', 'karaoke'],
#  ['toket', 'cewek', 'kayak', 'gini', 'enak', 'buat', 'di', 'emut'],
#  ['cara', 'ngocok', 'kontol', 'biar', 'cepat', 'crot', 'kayak', 'gini', 'nih'],
#  ['ngentot', 'cewek', 'jembut', 'tebal', 'sampai', 'crot'],
#  ['video', 'bokep', 'terpanas', 'artis', 'indonesia', 'ariel', 'luna', 'maya'],
#  ['cewek', 'cantik', 'dipkasa', 'mesum', 'di', 'bigo', 'live', 'hot'],
#  ['abg', 'polos', 'bandung', 'keenakan'],
#  ['ngentot', 'dengan', 'pacar', 'di', 'toilet', 'kampus'],
#  ['ngajak', 'cewek', 'bispak', 'toge', 'ngentot', 'di', 'hotel'],
#  ['nurul', 'abg', 'cantik', 'lagi', 'sange', 'sambil', 'mainin', 'memek'],
#  ['video', 'amatir', 'ngentot', 'cewek', 'bokingan'],
#  ['video', 'abg', 'ngentot', 'dalam', 'mobil'],
#  ['young',
#   'sg',
#   'girl',
#   'with',
#   'blowjob',
#   'skills',
#   'well',
#   'beyond',
#   'her',
#   'age'],
#  ['tante', 'girang', 'toket', 'gede', 'masturbasi', 'dalam', 'toilet'],
#  ['video', 'tsabita', 'bugil', 'remas', 'toge'],
#  ['young',
#   'sg',
#   'girl',
#   'with',
#   'blowjob',
#   'skills',
#   'well',
#   'beyond',
#   'her',
#   'age'],
#  ['desahan', 'cewek', 'korea', 'kalau', 'lagi', 'ngentot'],
#  ['janda', 'bra', 'biru'],
#  ['ngentot',
#   'memek',
#   'tembem',
#   'tanpa',
#   'crot',
#   'di',
#   'dalam',
#   'huh',
#   'ga',
#   'enak'],
#  ['perjuangan', 'cewek', 'abg', 'ngeluarin', 'peju', 'pacar'],
#  ['cewek', 'korea', 'cantik', 'pamer', 'payudara'],
#  ['toilet', 'recording'],
#  ['malu', 'tapi', 'mau', 'berbagi'],
#  ['mahasiswi', 'simpanan', 'habis', 'digangbang'],
#  ['tante', 'stw', 'lagi', 'gatel', 'colok', 'memek', 'make', 'terong'],
#  ['video', 'bokep', 'abg', 'imut', 'cantik', 'banget', 'bugil', 'sange'],
#  ['udah', 'dewasa', 'masih', 'suka', 'nenen'],
#  ['bibir', 'sama', 'tubuhnya', 'sexy', 'banget'],
#  ['masih', 'abg', 'udah', 'jago', 'muasin', 'pacar'],
#  ['skandal', 'bokep', 'jadul', 'tapi', 'spesial'],
#  ['ngentot', 'si', 'jamal', 'jamblay', 'malam'],
#  ['tante', 'binal', 'bj', 'sambil', 'merokok'],
#  ['video', 'cewek', 'senam', 'yoga', 'sambil', 'bugil'],
#  ['si', 'chubby', 'perlu', 'uang'],
#  ['sesi', 'pemotretan', 'model', 'seksi', 'asal', 'thailand'],
#  ['janda', 'muda', 'suka', 'mekinya', 'digenjot', 'duda', 'kaya'],
#  ['video', 'ngentot', 'pacar', 'payudara', 'besar', 'emang', 'nikmat'],
#  ['masih', 'muda', 'kecanduan', 'ml'],
#  ['video', 'mesum', 'abg', 'jaman', 'now'],
#  ['toketnya', 'masih', 'ranum'],
#  ['tante', 'stw', 'lagi', 'gatel', 'colok', 'memek', 'make', 'terong'],
#  ['video', 'cewek', 'pecah', 'perawan'],
#  ['nikmatnya',
#   'tiap',
#   'hari',
#   'dilayani',
#   'ngentot',
#   'sama',
#   'istri',
#   'muda',
#   'yang',
#   'semok'],
#  ['pelatih',
#   'fitnes',
#   'ngajarin',
#   'pelanggan',
#   'olahraga',
#   'dengan',
#   'gaya',
#   'ngentot'],
#  ['bokep', 'cewek', 'amoy', 'nyepong', 'kontol', 'bule'],
#  ['spg', 'madiun', 'ml', 'live', 'di', 'bigo', 'hot', 'show'],
#  ['contoh', 'pose', 'yang', 'bisa', 'bikin', 'cowok', 'sange'],
#  ['entahlah',
#   'apa',
#   'yang',
#   'cocok',
#   'untuk',
#   'cewek',
#   'berjilbab',
#   'sange',
#   'ini'],
#  ['cewek', 'sma', 'dientot', 'guru', 'olahraga'],
#  ['mahasiswi',
#   'nyepong',
#   'kontol',
#   'pacar',
#   'dalam',
#   'kelas',
#   'saat',
#   'yang',
#   'lain',
#   'lagi',
#   'sibuk',
#   'belajar'],
#  ['video', 'opa', 'ngentot', 'ponakan', 'sma'],
#  ['bini', 'tetangga', 'memang', 'liar'],
#  ['masturbasi', 'pakai', 'mesin', 'part'],
#  ['skandal', 'cewek', 'abg', 'gatel', 'ketahuan', 'mesum', 'di', 'warnet'],
#  ['video', 'bokep', 'gratis', 'cewek', 'cantik', 'ngentot'],
#  ['tetek', 'gede', 'tante', 'girang', 'yang', 'seksi'],
#  ['cewek',
#   'abg',
#   'di',
#   'kasih',
#   'obat',
#   'perangsang',
#   'liat',
#   'aja',
#   'matanya',
#   'merah',
#   'gitu'],
#  ['awek', 'melayu', 'ketat', 'darah', 'perawan', 'kota'],
#  ['agen', 'palsu', 'ngentot', 'cewe', 'berkacamata', 'hot'],
#  ['tante', 'girang', 'mabuk', 'berondong'],
#  ['ngentot', 'pacar', 'berjilbab', 'di', 'hotel'],
#  ['games', 'kocak', 'yang', 'bikin', 'ente', 'bisa', 'ngenot', 'sepuasnya'],
#  ['jilbab', 'merah', 'kacamata'],
#  ['angela', 'white', 'sex', 'addict'],
#  ['bokep', 'tante', 'berjilbab', 'kualitas', 'hd'],
#  ['amazing', 'indo', 'masturbating', 'girls', 'videos'],
#  ['ngentot', 'sampai', 'crot', 'di', 'muka'],
#  ['cewek', 'cantik', 'dipkasa', 'mesum', 'di', 'bigo', 'live', 'hot'],
#  ['juicy', 'peach'],
#  ['video', 'cewek', 'belajar', 'nyepong', 'kontol'],
#  ['bokep', 'cewek', 'smp', 'pramuka', 'berkaca', 'mata'],
#  ['ngentot', 'memek', 'tembem', 'sampai', 'berbusa'],
#  ['bokep', 'perempuan', 'hypersex'],
#  ['video', 'bugil', 'naely', 'sexy', 'goyang', 'bugil'],
#  ['bokep', 'cewek', 'bandung'],
#  ['video', 'model', 'indo', 'nyepong'],
#  ['ngentot', 'selingkuhan', 'berjilbab', 'hijau'],
#  ['istri', 'semok', 'lebih', 'suka', 'di', 'atas'],
#  ['bispak', 'memek', 'sempit', 'beraksi', 'dengan', 'bule'],
#  ['keburu',
#   'sange',
#   'ngentot',
#   'selingkuhan',
#   'di',
#   'hotel',
#   'tanpa',
#   'buka',
#   'baju'],
#  ['skandal', 'bokep', 'dewi', 'ngentot', 'dalam', 'semak'],
#  ['abg',
#   'baju',
#   'biru',
#   'cuman',
#   'pasrah',
#   'saat',
#   'kontol',
#   'mulai',
#   'masuk',
#   'lewat',
#   'memek'],
#  ['video', 'cewek', 'cantik', 'sange'],
#  ['mencoba', 'merawanin', 'pantat', 'istri'],
#  ['sekretaris', 'ngentot', 'sama', 'bos', 'sepulang', 'kerja'],
#  ['cewek', 'abg', 'korea', 'nyepong', 'kontol', 'sepulang', 'sekolah'],
#  ['bokep', 'jepang', 'tokyo', 'hot', 'tsuna', 'kimura'],
#  ['video', 'bokep', 'cewek', 'berjilbab', 'vethree'],
#  ['bokep',
#   'jepang',
#   'bikin',
#   'galau',
#   'apalagi',
#   'ceweknya',
#   'teriak',
#   'kayak',
#   'gini'],
#  ['scandal', 'bokep', 'pns', 'ngentot', 'dalam', 'mobil'],
#  ['wanita', 'karir', 'ini', 'ngentot', 'demi', 'uang'],
#  ['maling', 'perhiasan', 'kena', 'batunya'],
#  ['bule', 'cantik', 'nyepong', 'kontol'],
#  ['kimcil', 'mainin', 'memek'],
#  ['ngentot', 'istri', 'dari', 'belakang'],
#  ['spg', 'genit', 'mesum', 'di', 'hotel'],
#  ['cewek', 'bule', 'emang', 'paling', 'doyan', 'colok', 'memek', 'sendiri'],
#  ['tante', 'mendesah', 'sambil', 'minta', 'pejuh'],
#  ['cewek', 'berjilbab', 'biru', 'nyepong', 'kontol', 'pacar'],
#  ['wwe', 'diva', 'paige', 'full', 'sex', 'tape', 'video', 'leaked', 'video'],
#  ['video',
#   'ayah',
#   'tiri',
#   'ngentot',
#   'anak',
#   'tiri',
#   'pas',
#   'lagi',
#   'tidur',
#   'nyenyak'],
#  ['ngentot', 'pacar', 'sangek', 'seharian'],
#  ['memek', 'kyle', 'quinn', 'gurih', 'banget'],
#  ['body', 'cewek', 'yang', 'diidamkan', 'tiap', 'lelaki'],
#  ['memek', 'lezat', 'abg'],
#  ['tusuk', 'aku', 'bang'],
#  ['video', 'tante', 'kesepian', 'ngentot', 'di', 'hutan'],
#  ['kimcil', 'panggilan', 'surabaya'],
#  ['cewek', 'berjilbab', 'pink', 'lagi', 'nyepong', 'kontol', 'kekasih'],
#  ['abg',
#   'masturbasi',
#   'sampai',
#   'keluar',
#   'cairan',
#   'di',
#   'memek',
#   'merahnya'],
#  ['abg', 'cina', 'amoy', 'di', 'gangbang', 'rame', 'rame'],
#  ['suami', 'itri', 'ketahuan', 'ngentot', 'di', 'rumah', 'teman'],
#  ['abg', 'berjilbab', 'mesum', 'di', 'mobil'],
#  ['video', 'skandal', 'bokep', 'ali', 'dan', 'ani'],
#  ['buat', 'yang', 'jauh', 'disana'],
#  ['sepupu', 'pulang', 'sekolah', 'langsung', 'ngentot'],
#  ['ngewe', 'sama', 'lonte', 'amoy', 'sampai', 'memeknya', 'memerah'],
#  ['hayden', 'hennessy', 'in', 'yoga', 'and', 'sexercise'],
#  ['abg', 'jepang', 'berseragam', 'sekolah', 'binal'],
#  ['video', 'cewek', 'abg', 'sange'],
#  ['ngentot', 'dengan', 'pacar', 'seksi', 'dan', 'cantik'],
#  ['video', 'bule', 'ngentot', 'dengan', 'cewek', 'jepang', 'cantik'],
#  ['coli', 'sambil', 'nonton', 'bokep', 'malah', 'ketahuan', 'sepupu'],
#  ['nikmatnya', 'crot', 'di', 'memek', 'teman', 'kerja'],
#  ['seminggu', 'pacaran', 'udah', 'langsung', 'mesum', 'di', 'kos', 'kosan'],
#  ['semok', 'colmek', 'dikamar', 'mandi'],
#  ['bersetubuh', 'dengan', 'tante', 'gendut'],
#  ['ngentot', 'sama', 'selingkuhan', 'sambil', 'telponan', 'sama', 'suami'],
#  ['bokep', 'shintamedina', 'part'],
#  ['ngentot', 'memek', 'tembeb', 'mahasiswi', 'tanpa', 'bulu'],
#  ['ngentot', 'pacar', 'seksi', 'sambil', 'direkam', 'teman'],
#  ['cewek',
#   'cantik',
#   'mendesah',
#   'sambil',
#   'colok',
#   'memek',
#   'sempit',
#   'miliknya'],
#  ['tante', 'semok', 'beraksi', 'depan', 'webcam'],
#  ['foursome', 'didalam', 'kereta'],
#  ['bokep', 'abg', 'semok', 'memek', 'tanpa', 'bulu'],
#  ['anak', 'tiri'],
#  ['cewek', 'berjilbab', 'mastrubasi', 'dengan', 'dildo'],
#  ['bokep', 'online', 'para', 'remaja', 'perawan', 'memek', 'mulus'],
#  ['video', 'bokep', 'filipina'],
#  ['cewek', 'abg', 'thailand', 'ngentot', 'karo', 'pacar'],
#  ['projek', 'di', 'tempat', 'kerja', 'melayu', 'malaysia'],
#  ['ngewe', 'abg', 'cantik', 'blasteran', 'arab', 'memek', 'mulus'],
#  ['tatapan', 'matanya', 'tajam', 'bener', 'oi'],
#  ['disepongin', 'selingkuhan', 'berstatus', 'janda', 'anak'],
#  ['meki', 'janda', 'anak', 'enak', 'banget'],
#  ['video', 'basahin', 'memek', 'janda', 'kembang', 'yang', 'sudah', 'sange'],
#  ...]

# %%
# Importing the built-in logging module
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# Creating the model and setting values for the various parameters
num_features = 300  # Word vector dimensionality
min_word_count = 5 # Minimum word count
num_workers = 4     # Number of parallel threads
context = 10        # Context window size
downsampling = 1e-3 # (0.001) Downsample setting for frequent words

# Initializing the train model
from gensim.models import word2vec
print("Training model....")
model = word2vec.Word2Vec(sentences,\
                          workers=num_workers,\
                          size=num_features,\
                          min_count=min_word_count,\
                          window=context,
                          sample=downsampling)

# To make the model memory efficient
model.init_sims(replace=True)

# Saving the model for later use. Can be loaded using Word2Vec.load()
model_name = "bondowoso"
model.save(model_name)
# Out:
# 2018-07-04 20:23:29,402 : INFO : collecting all words and their counts
# 2018-07-04 20:23:29,403 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-07-04 20:23:29,409 : INFO : collected 3013 word types from a corpus of 14335 raw words and 1782 sentences
# 2018-07-04 20:23:29,409 : INFO : Loading a fresh vocabulary
# 2018-07-04 20:23:29,413 : INFO : min_count=5 retains 588 unique words (19% of original 3013, drops 2425)
# 2018-07-04 20:23:29,414 : INFO : min_count=5 leaves 10499 word corpus (73% of original 14335, drops 3836)
# 2018-07-04 20:23:29,417 : INFO : deleting the raw counts dictionary of 3013 items
# 2018-07-04 20:23:29,418 : INFO : sample=0.001 downsamples 66 most-common words
# 2018-07-04 20:23:29,418 : INFO : downsampling leaves estimated 7775 word corpus (74.1% of prior 10499)
# 2018-07-04 20:23:29,420 : INFO : estimated required memory for 588 words and 300 dimensions: 1705200 bytes
# 2018-07-04 20:23:29,421 : INFO : resetting layer weights
# 2018-07-04 20:23:29,448 : INFO : training model with 4 workers on 588 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2018-07-04 20:23:29,457 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-07-04 20:23:29,463 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-04 20:23:29,470 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-04 20:23:29,475 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-04 20:23:29,476 : INFO : EPOCH - 1 : training on 14335 raw words (7735 effective words) took 0.0s, 370361 effective words/s
# 2018-07-04 20:23:29,483 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-07-04 20:23:29,487 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-04 20:23:29,493 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-04 20:23:29,503 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-04 20:23:29,504 : INFO : EPOCH - 2 : training on 14335 raw words (7774 effective words) took 0.0s, 380791 effective words/s
# 2018-07-04 20:23:29,511 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-07-04 20:23:29,515 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-04 20:23:29,520 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-04 20:23:29,530 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-04 20:23:29,531 : INFO : EPOCH - 3 : training on 14335 raw words (7785 effective words) took 0.0s, 392864 effective words/s
# 2018-07-04 20:23:29,538 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-07-04 20:23:29,542 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-04 20:23:29,554 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-04 20:23:29,555 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-04 20:23:29,557 : INFO : EPOCH - 4 : training on 14335 raw words (7757 effective words) took 0.0s, 400040 effective words/s
# 2018-07-04 20:23:29,565 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-07-04 20:23:29,569 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-04 20:23:29,573 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-04 20:23:29,584 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-04 20:23:29,585 : INFO : EPOCH - 5 : training on 14335 raw words (7724 effective words) took 0.0s, 387650 effective words/s
# 2018-07-04 20:23:29,588 : INFO : training on a 71675 raw words (38775 effective words) took 0.1s, 278197 effective words/s
# 2018-07-04 20:23:29,589 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2018-07-04 20:23:29,590 : INFO : precomputing L2-norms of word weight vectors
# 2018-07-04 20:23:29,598 : INFO : saving Word2Vec object under bondowoso, separately None
# 2018-07-04 20:23:29,599 : INFO : not storing attribute vectors_norm
# 2018-07-04 20:23:29,600 : INFO : not storing attribute cum_table
# Training model....
# 2018-07-04 20:23:29,619 : INFO : saved bondowoso

# %%
# Few tests: This will print the odd word among them 
model.wv.doesnt_match("aku ngentot anda sex".split())
# Out:
# 2018-07-04 20:23:29,624 : WARNING : vectors for words {'aku'} are not present in the model, ignoring these words
# 'ngentot'

# %%
# This will print the most similar words present in the model
model.wv.most_similar("crot")
# Out:
# [('di', 0.9991635680198669),
#  ('pria', 0.9991549253463745),
#  ('akan', 0.9991517066955566),
#  ('untuk', 0.9991499781608582),
#  ('dapat', 0.9991472959518433),
#  ('seks', 0.999146580696106),
#  ('tidak', 0.999146580696106),
#  ('yang', 0.9991453886032104),
#  ('anda', 0.9991423487663269),
#  ('dan', 0.9991397261619568)]

# %%
#This will give the total number of words in the vocabolary created from this dataset
model.wv.syn0.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
# (588, 300)

# %%
# Function to average all word vectors in a paragraph
def featureVecMethod(words, model, num_features):
    # Pre-initialising empty numpy array for speed
    featureVec = np.zeros(num_features,dtype="float32")
    nwords = 0
    
    #Converting Index2Word which is a list to a set for better speed in the execution.
    index2word_set = set(model.wv.index2word)
    
    for word in  words:
        if word in index2word_set:
            nwords = nwords + 1
            featureVec = np.add(featureVec,model[word])
    
    # Dividing the result by number of words to get average
    featureVec = np.divide(featureVec, nwords)
    return featureVec

# %%
# Function for calculating the average feature vector
def getAvgFeatureVecs(reviews, model, num_features):
    counter = 0
    reviewFeatureVecs = np.zeros((len(reviews),num_features),dtype="float32")
    for review in reviews:
        # Printing a status message every 1000th review
        if counter%10 == 0:
            print("Review %d of %d"%(counter,len(reviews)))
            
        reviewFeatureVecs[counter] = featureVecMethod(review, model, num_features)
        counter = counter+1
        
    return reviewFeatureVecs

# %%
# Calculating average feature vector for training set
clean_train_reviews = []
for review in df_train['review']:
    clean_train_reviews.append(review_wordlist(review, remove_stopwords=True))
    
trainDataVecs = getAvgFeatureVecs(clean_train_reviews, model, num_features)
# Out:
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Review 0 of 1764
# Review 10 of 1764
# Review 20 of 1764
# Review 30 of 1764
# Review 40 of 1764
# Review 50 of 1764
# Review 60 of 1764
# Review 70 of 1764
# Review 80 of 1764
# Review 90 of 1764
# Review 100 of 1764
# Review 110 of 1764
# Review 120 of 1764
# Review 130 of 1764
# Review 140 of 1764
# Review 150 of 1764
# Review 160 of 1764
# Review 170 of 1764
# Review 180 of 1764
# Review 190 of 1764
# Review 200 of 1764
# Review 210 of 1764
# Review 220 of 1764
# Review 230 of 1764
# Review 240 of 1764
# Review 250 of 1764
# Review 260 of 1764
# Review 270 of 1764
# Review 280 of 1764
# Review 290 of 1764
# Review 300 of 1764
# Review 310 of 1764
# Review 320 of 1764
# Review 330 of 1764
# Review 340 of 1764
# Review 350 of 1764
# Review 360 of 1764
# Review 370 of 1764
# Review 380 of 1764
# Review 390 of 1764
# Review 400 of 1764
# Review 410 of 1764
# Review 420 of 1764
# Review 430 of 1764
# Review 440 of 1764
# Review 450 of 1764
# Review 460 of 1764
# Review 470 of 1764
# Review 480 of 1764
# Review 490 of 1764
# Review 500 of 1764
# Review 510 of 1764
# Review 520 of 1764
# Review 530 of 1764
# Review 540 of 1764
# Review 550 of 1764
# Review 560 of 1764
# Review 570 of 1764
# Review 580 of 1764
# Review 590 of 1764
# Review 600 of 1764
# Review 610 of 1764
# Review 620 of 1764
# Review 630 of 1764
# Review 640 of 1764
# Review 650 of 1764
# Review 660 of 1764
# Review 670 of 1764
# Review 680 of 1764
# Review 690 of 1764
# Review 700 of 1764
# Review 710 of 1764
# Review 720 of 1764
# Review 730 of 1764
# Review 740 of 1764
# Review 750 of 1764
# Review 760 of 1764
# Review 770 of 1764
# Review 780 of 1764
# Review 790 of 1764
# Review 800 of 1764
# Review 810 of 1764
# Review 820 of 1764
# Review 830 of 1764
# Review 840 of 1764
# Review 850 of 1764
# Review 860 of 1764
# Review 870 of 1764
# Review 880 of 1764
# Review 890 of 1764
# Review 900 of 1764
# Review 910 of 1764
# Review 920 of 1764
# Review 930 of 1764
# Review 940 of 1764
# Review 950 of 1764
# Review 960 of 1764
# Review 970 of 1764
# Review 980 of 1764
# Review 990 of 1764
# Review 1000 of 1764
# Review 1010 of 1764
# Review 1020 of 1764
# Review 1030 of 1764
# Review 1040 of 1764
# Review 1050 of 1764
# Review 1060 of 1764
# Review 1070 of 1764
# Review 1080 of 1764
# Review 1090 of 1764
# Review 1100 of 1764
# Review 1110 of 1764
# Review 1120 of 1764
# Review 1130 of 1764
# Review 1140 of 1764
# Review 1150 of 1764
# Review 1160 of 1764
# Review 1170 of 1764
# Review 1180 of 1764
# Review 1190 of 1764
# Review 1200 of 1764
# Review 1210 of 1764
# Review 1220 of 1764
# Review 1230 of 1764
# Review 1240 of 1764
# Review 1250 of 1764
# Review 1260 of 1764
# Review 1270 of 1764
# Review 1280 of 1764
# Review 1290 of 1764
# Review 1300 of 1764
# Review 1310 of 1764
# Review 1320 of 1764
# Review 1330 of 1764
# Review 1340 of 1764
# Review 1350 of 1764
# Review 1360 of 1764
# Review 1370 of 1764
# Review 1380 of 1764
# Review 1390 of 1764
# Review 1400 of 1764
# Review 1410 of 1764
# Review 1420 of 1764
# Review 1430 of 1764
# Review 1440 of 1764
# Review 1450 of 1764
# Review 1460 of 1764
# Review 1470 of 1764
# Review 1480 of 1764
# Review 1490 of 1764
# Review 1500 of 1764
# Review 1510 of 1764
# Review 1520 of 1764
# Review 1530 of 1764
# Review 1540 of 1764
# Review 1550 of 1764
# Review 1560 of 1764
# Review 1570 of 1764
# Review 1580 of 1764
# Review 1590 of 1764
# Review 1600 of 1764
# Review 1610 of 1764
# Review 1620 of 1764
# Review 1630 of 1764
# Review 1640 of 1764
# Review 1650 of 1764
# Review 1660 of 1764
# Review 1670 of 1764
# Review 1680 of 1764
# Review 1690 of 1764
# Review 1700 of 1764
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()
# Review 1710 of 1764
# Review 1720 of 1764
# Review 1730 of 1764
# Review 1740 of 1764
# Review 1750 of 1764
# Review 1760 of 1764

# %%
trainDataVecs
# Out:
# array([[-0.04844277,  0.00123369,  0.02288424, ...,  0.08489322,
#         -0.0349283 , -0.03653152],
#        [-0.04801343,  0.00170678,  0.02287277, ...,  0.08455166,
#         -0.03478274, -0.03667087],
#        [-0.04950338,  0.00100669,  0.02254903, ...,  0.08412886,
#         -0.03488251, -0.03707476],
#        ...,
#        [-0.0466266 ,  0.00098727,  0.02253562, ...,  0.08436478,
#         -0.03520383, -0.03676179],
#        [-0.04754343,  0.00199392,  0.01849172, ...,  0.08526554,
#         -0.03602573, -0.03447072],
#        [-0.04962426,  0.00355955,  0.02188067, ...,  0.08356854,
#         -0.03416751, -0.03793616]], dtype=float32)

# %%
# Calculating average feature vactors for test set     
clean_test_reviews = []
for review in df_test["review"]:
    clean_test_reviews.append(review_wordlist(review,remove_stopwords=True))
    
testDataVecs = getAvgFeatureVecs(clean_test_reviews, model, num_features)
# Out:
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Review 0 of 442
# Review 10 of 442
# Review 20 of 442
# Review 30 of 442
# Review 40 of 442
# Review 50 of 442
# Review 60 of 442
# Review 70 of 442
# Review 80 of 442
# Review 90 of 442
# Review 100 of 442
# Review 110 of 442
# Review 120 of 442
# Review 130 of 442
# Review 140 of 442
# Review 150 of 442
# Review 160 of 442
# Review 170 of 442
# Review 180 of 442
# Review 190 of 442
# Review 200 of 442
# Review 210 of 442
# Review 220 of 442
# Review 230 of 442
# Review 240 of 442
# Review 250 of 442
# Review 260 of 442
# Review 270 of 442
# Review 280 of 442
# Review 290 of 442
# Review 300 of 442
# Review 310 of 442
# Review 320 of 442
# Review 330 of 442
# Review 340 of 442
# Review 350 of 442
# Review 360 of 442
# Review 370 of 442
# Review 380 of 442
# Review 390 of 442
# Review 400 of 442
# Review 410 of 442
# Review 420 of 442
# Review 430 of 442
# Review 440 of 442
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()

# %%
testDataVecs
# Out:
# array([[-0.04900429,  0.00196793,  0.02295567, ...,  0.08400487,
#         -0.03508969, -0.0368119 ],
#        [-0.0485411 ,  0.00187539,  0.02306277, ...,  0.08453841,
#         -0.03500401, -0.03674699],
#        [-0.04919091,  0.00193121,  0.02263741, ...,  0.08557057,
#         -0.03425348, -0.03715811],
#        ...,
#        [-0.04682363,  0.00333181,  0.02246306, ...,  0.08383805,
#         -0.03568291, -0.0352934 ],
#        [-0.0465318 ,  0.00138538,  0.02126272, ...,  0.0827901 ,
#         -0.03637518, -0.03743576],
#        [-0.04847575,  0.00130077,  0.02321327, ...,  0.08484703,
#         -0.03638764, -0.0365868 ]], dtype=float32)

# %%
# df_train = df_train.fillna(0)

# %%
col_mean = np.nanmean(trainDataVecs, axis=0)
inds = np.where(np.isnan(trainDataVecs))
trainDataVecs[inds] = np.take(col_mean, inds[1])

# %%
# df_train

# %%
# Fitting a random forest classifier to the training data
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 100)
print("Fitting random forest to training data....")    
forest = forest.fit(trainDataVecs, df_train["sentiment"])
# trainDataVecs
# Out:
# Fitting random forest to training data....

# %%
col_mean = np.nanmean(testDataVecs, axis=0)
inds = np.where(np.isnan(testDataVecs))
testDataVecs[inds] = np.take(col_mean, inds[1])

# %%
# df_test

# %%
result = forest.predict(testDataVecs)
result_str = []
for x in result:
    if x == 1:
        result_str.append("Positif")
    else :
        result_str.append("Negatif")

# %%
result_str
# Out:
# ['Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Positif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif',
#  'Negatif']

# %%
output = pd.DataFrame(data={"analyst":df_test["review"], "sentiment":result_str})

# %%
output
# Out:
#                                                analyst sentiment
# 0     jika terjadinya sekali-dua kali saja mungkin ...   Positif
# 1     hal ini bisa dikaitkan dengan meningkatnya im...   Positif
# 2     \n* sex : terhindar dari resiko atrofi (penge...   Positif
# 3     namun, jumlah rata-rata itu lebih besar dua k...   Positif
# 4     \n* sex : obat penenang yang paling aman di d...   Positif
# 5     itu sebabnya, jika anda mengalami masalah gan...   Positif
# 6     so, stop ya penggunaan obat kuat, beralihlah ...   Positif
# 7     tetapi jika terlalu sering dan terus dibiarka...   Positif
# 8     impiannya tentang kebahagiaan justru nyaris t...   Positif
# 9                                                        Positif
# 10    apalah artinya hubungan seks jika tidak diser...   Positif
# 11    tetapi begitu sibuk dengan anak-anak sehingga...   Positif
# 12                                       \nluar biasa    Positif
# 13    jadi pada saat penderita merasakan akan ejaku...   Positif
# 14    seseorang yang berhubungan seks secara teratu...   Positif
# 15           id atau email :  prostate_health@onclinic   Positif
# 16    lakukan sekarang untuk sehat selamanya! jika ...   Positif
# 17                              9050, bogor (0251) 831   Positif
# 18    erlich, seorang spesialis arthritis dari phil...   Positif
# 19    normalnya, ereksi bisa tercapai bila ada peni...   Positif
# 20                                                       Positif
# 21   kebanyakan pria menganggap merokok membuat ter...   Positif
# 22    \nseminggu 2x diinfus & terapi (biayanya luma...   Negatif
# 23    sementara itu, pria yang mengisap lebih dari ...   Positif
# 24    menurut riset american heart associations ann...   Positif
# 25                             000, surabaya (031) 547   Positif
# 26    turunkan kaki dan duduk di tepi ranjang selam...   Positif
# 27    tidak ada jalan lain kecuali menuntaskan sege...   Positif
# 28                    \n* sex : mengurangi berat badan   Positif
# 29    yang penting harus tepat berobatnya!” jack va...   Negatif
# ..                                                 ...       ...
# 412                               bokep dillion harper   Negatif
# 413                               jual pacar demi uang   Negatif
# 414                            ngentot anak orang kaya   Negatif
# 415  games kocak yang bikin ente bisa ngenot sepuas...   Negatif
# 416     video ngentot janda crot di mulut telan sperma   Negatif
# 417                      video ngentot cewek berjilbab   Negatif
# 418         awalnya dipijat malah nafsu pengen ngentot   Negatif
# 419  film dewasa jadul indo nafsu birahi membara ma...   Negatif
# 420                       ketangkap basah saat ngentot   Negatif
# 421               ngedoggy cewek paling cakep dikampus   Negatif
# 422           pramugari ml sama pilot di dalam pesawat   Negatif
# 423                               ngentot istri cantik   Negatif
# 424  joget dengan body kayak gini tetap aja bikin s...   Negatif
# 425                ngentot di hari ulang tahun pacarku   Negatif
# 426               video kimcil cantik lagi sange berat   Negatif
# 427                video cewek cina muda nyepong pacar   Negatif
# 428      bokep jilbabers berkacamata nyepong di toilet   Negatif
# 429                             kimcil abg di gangbang   Negatif
# 430             akibat istri di tinggal pergi kelamaan   Negatif
# 431         video tkw edan, bugil sambil ngoceh-ngoceh   Negatif
# 432           video ngentot adik teman yang masih lugu   Negatif
# 433                            ngentot anak bispak sma   Negatif
# 434               ngentot pacar sambil mainan hadphone   Negatif
# 435  ngentot istri bokong semong berkaca mata = lua...   Negatif
# 436                   bule ngentot dengan bispak binal   Negatif
# 437                          di wot sama toge bra pink   Negatif
# 438                      2 cewek cantik rebutan kontol   Negatif
# 439               ngentot mahasiswo cantik dalam mobil   Negatif
# 440  kelakuan cewek asrama putri lagi belajar jadi ...   Negatif
# 441                     cewek cantik bugil dikontrakan   Negatif
#
# [442 rows x 2 columns]

# %%
# model for all model visualitation
import tensorflow as tf
from tensorflow.contrib.tensorboard.plugins import projector

# %%
def visualize(model, output_path):
    meta_file = "bdg_bdws.tsv"
    placeholder = np.zeros((len(model.wv.index2word), 32))

    with open(os.path.join(output_path,meta_file), 'wb') as file_metadata:
        for i, word in enumerate(model.wv.index2word):
            placeholder[i] = model[word]
            # temporary solution for https://github.com/tensorflow/tensorflow/issues/9094
            if word == '':
                print("Emply Line, should replecaed by any thing else, or will cause a bug of tensorboard")
                file_metadata.write("{0}".format('<Empty Line>').encode('utf-8') + b'\n')
            else:
                file_metadata.write("{0}".format(word).encode('utf-8') + b'\n')

    # define the model without training
    sess = tf.InteractiveSession()

    embedding = tf.Variable(placeholder, trainable = False, name = 'bdg_bdws')
    tf.global_variables_initializer().run()

    saver = tf.train.Saver()
    writer = tf.summary.FileWriter(output_path, sess.graph)

    # adding into projector
    config = projector.ProjectorConfig()
    embed = config.embeddings.add()
    embed.tensor_name = 'bdg_bdws'
    embed.metadata_path = meta_file

    # Specify the width and height of a single thumbnail.
    projector.visualize_embeddings(writer, config)
    saver.save(sess, os.path.join(output_path,'bdg_bdws.ckpt'))
    print('Run `tensorboard --logdir={0}` to run visualize result on tensorboard'.format(output_path))

# %%
corpus = negatif + positif

# %%
tok_corp = [nltk.word_tokenize(sent) for sent in corpus]

# %%
model_viz = gensim.models.Word2Vec(tok_corp,min_count=1,size=32)
# Out:
# 2018-07-04 20:24:14,679 : INFO : collecting all words and their counts
# 2018-07-04 20:24:14,682 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-07-04 20:24:14,691 : INFO : collected 3566 word types from a corpus of 19189 raw words and 2206 sentences
# 2018-07-04 20:24:14,692 : INFO : Loading a fresh vocabulary
# 2018-07-04 20:24:14,700 : INFO : min_count=1 retains 3566 unique words (100% of original 3566, drops 0)
# 2018-07-04 20:24:14,701 : INFO : min_count=1 leaves 19189 word corpus (100% of original 19189, drops 0)
# 2018-07-04 20:24:14,713 : INFO : deleting the raw counts dictionary of 3566 items
# 2018-07-04 20:24:14,715 : INFO : sample=0.001 downsamples 48 most-common words
# 2018-07-04 20:24:14,716 : INFO : downsampling leaves estimated 16012 word corpus (83.4% of prior 19189)
# 2018-07-04 20:24:14,739 : INFO : estimated required memory for 3566 words and 32 dimensions: 2695896 bytes
# 2018-07-04 20:24:14,740 : INFO : resetting layer weights
# 2018-07-04 20:24:14,792 : INFO : training model with 3 workers on 3566 vocabulary and 32 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-07-04 20:24:14,805 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-04 20:24:14,818 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-04 20:24:14,829 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-04 20:24:14,834 : INFO : EPOCH - 1 : training on 19189 raw words (15981 effective words) took 0.0s, 460295 effective words/s
# 2018-07-04 20:24:14,848 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-04 20:24:14,866 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-04 20:24:14,870 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-04 20:24:14,872 : INFO : EPOCH - 2 : training on 19189 raw words (16040 effective words) took 0.0s, 562099 effective words/s
# 2018-07-04 20:24:14,882 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-04 20:24:14,902 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-04 20:24:14,906 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-04 20:24:14,908 : INFO : EPOCH - 3 : training on 19189 raw words (16024 effective words) took 0.0s, 556916 effective words/s
# 2018-07-04 20:24:14,916 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-04 20:24:14,931 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-04 20:24:14,941 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-04 20:24:14,942 : INFO : EPOCH - 4 : training on 19189 raw words (16038 effective words) took 0.0s, 600382 effective words/s
# 2018-07-04 20:24:14,950 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-04 20:24:14,965 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-04 20:24:14,974 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-04 20:24:14,976 : INFO : EPOCH - 5 : training on 19189 raw words (15987 effective words) took 0.0s, 628402 effective words/s
# 2018-07-04 20:24:14,977 : INFO : training on a 95945 raw words (80070 effective words) took 0.2s, 435886 effective words/s
# 2018-07-04 20:24:14,978 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
# model_viz.most_similar('ngentot')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# 2018-07-04 20:24:21,307 : INFO : precomputing L2-norms of word weight vectors
# [(',', 0.9990885853767395),
#  ('yang', 0.9988171458244324),
#  ('di', 0.9984101057052612),
#  ('dan', 0.9983388781547546),
#  ('akan', 0.998320460319519),
#  ('dengan', 0.998254120349884),
#  ('dari', 0.9981817007064819),
#  ('bahwa', 0.9979394674301147),
#  ('untuk', 0.9979209899902344),
#  ('bisa', 0.9978971481323242)]

# %%
visualize(model_viz,"./")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys
# Run `tensorboard --logdir=./` to run visualize result on tensorboard
